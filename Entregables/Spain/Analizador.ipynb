# %%
# Si te faltan dependencias, descomenta y ejecuta:
# !pip install torch transformers sentencepiece tiktoken protobuf

import json
from transformers import pipeline, logging

# Suprimir warnings de Transformers
logging.set_verbosity_error()

# Forzar uso de CPU (cambia a 0 para GPU si tu VRAM lo permite)
DEVICE = -1

# 1) Configuración de pipelines
sentiment_pipe = pipeline(
    "sentiment-analysis",
    model="cardiffnlp/twitter-roberta-base-sentiment-latest",
    tokenizer="cardiffnlp/twitter-roberta-base-sentiment-latest",
    device=DEVICE
)
emotion_pipe = pipeline(
    "text-classification",
    model="cardiffnlp/twitter-roberta-base-emotion",
    tokenizer="cardiffnlp/twitter-roberta-base-emotion",
    return_all_scores=True,
    device=DEVICE
)
hate_pipe = pipeline(
    "zero-shot-classification",
    model="joeddav/xlm-roberta-large-xnli",
    tokenizer="joeddav/xlm-roberta-large-xnli",
    device=DEVICE
)
translation_pipe = pipeline(
    "translation",
    model="Helsinki-NLP/opus-mt-mul-en",
    tokenizer="Helsinki-NLP/opus-mt-mul-en",
    device=DEVICE
)
summarization_pipe = pipeline(
    "summarization",
    model="sshleifer/distilbart-cnn-12-6",
    tokenizer="sshleifer/distilbart-cnn-12-6",
    device=DEVICE
)

# 2) Función de análisis (igual que antes)
def analyze_text(text, lang):
    text = text or ""
    if not text.strip():
        return {"sentiment": None, "emotions": [], "hate": None, "translation": None, "summary": None}
    res = {}
    # Sentiment
    s = sentiment_pipe(text)[0]
    res["sentiment"] = {"label": s["label"], "score": float(s["score"])}
    # Emotions top 3
    emos = emotion_pipe(text)[0]
    top3 = sorted(emos, key=lambda x: x["score"], reverse=True)[:3]
    res["emotions"] = [{"label": e["label"], "score": float(e["score"])} for e in top3]
    # Hate vs Not Hate
    try:
        z = hate_pipe(text, candidate_labels=["hate", "not hate"])
        res["hate"] = {"label": z["labels"][0], "score": float(z["scores"][0])}
    except ValueError:
        res["hate"] = None
    # Translation
    if lang != "en":
        tr = translation_pipe(text, max_length=256)[0]["translation_text"]
        res["translation"] = tr
        summary_input = tr
    else:
        res["translation"] = text
        summary_input = text
    # Summarization dinámico
    tok = summarization_pipe.tokenizer
    ids = tok.encode(summary_input, return_tensors="pt")[0]
    max_len = max(5, min(60, len(ids) - 2))
    sm = summarization_pipe(summary_input, max_length=max_len, min_length=5)[0]["summary_text"]
    res["summary"] = sm
    return res

# 3) Cargar datos
input_path = "tweets_griegos_anotados_finales.json"
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)

lang = "el"  # 'el' para griego

# 4) Procesar en dos trozos: indices 0–499 y 500–999
ranges = [(0, 500), (500, 1000)]
for start, end in ranges:
    subset = data[start:end]
    total = len(subset)
    output_path = f"tweets_griegos_evaluados_{start+1}_{start+total}.json"
    
    for idx, item in enumerate(subset, start=1):
        print(f"Procesando chunk {start+1}-{end}, tweet {idx}/{total}")
        # tweet principal
        item["analysis"] = analyze_text(item.get("tweet", ""), lang)
        # todas las replies
        for r_idx, reply in enumerate(item.get("replies", []), start=1):
            reply["analysis"] = analyze_text(reply.get("reply", ""), lang)
    
    # guardar este chunk
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(subset, f, ensure_ascii=False, indent=2)
    print(f"Chunk {start+1}-{start+total} completado. Salvo en {output_path}\n")

# %%
# Si te faltan dependencias, descomenta y ejecuta:
# !pip install torch transformers sentencepiece tiktoken protobuf

import json
from transformers import pipeline, logging

# Suprimir warnings de Transformers
logging.set_verbosity_error()

# Forzar uso de CPU (cambia a 0 para GPU si tu VRAM lo permite)
DEVICE = 0

# 1) Configuración de pipelines
sentiment_pipe = pipeline(
    "sentiment-analysis",
    model="cardiffnlp/twitter-roberta-base-sentiment-latest",
    tokenizer="cardiffnlp/twitter-roberta-base-sentiment-latest",
    device=DEVICE
)
emotion_pipe = pipeline(
    "text-classification",
    model="cardiffnlp/twitter-roberta-base-emotion",
    tokenizer="cardiffnlp/twitter-roberta-base-emotion",
    return_all_scores=True,
    device=DEVICE
)
hate_pipe = pipeline(
    "zero-shot-classification",
    model="joeddav/xlm-roberta-large-xnli",
    tokenizer="joeddav/xlm-roberta-large-xnli",
    device=DEVICE
)
translation_pipe = pipeline(
    "translation",
    model="Helsinki-NLP/opus-mt-mul-en",
    tokenizer="Helsinki-NLP/opus-mt-mul-en",
    device=DEVICE
)
summarization_pipe = pipeline(
    "summarization",
    model="sshleifer/distilbart-cnn-12-6",
    tokenizer="sshleifer/distilbart-cnn-12-6",
    device=DEVICE
)

# 2) Función de análisis (igual que antes)
def analyze_text(text, lang):
    text = text or ""
    if not text.strip():
        return {"sentiment": None, "emotions": [], "hate": None, "translation": None, "summary": None}
    res = {}
    # Sentiment
    s = sentiment_pipe(text)[0]
    res["sentiment"] = {"label": s["label"], "score": float(s["score"])}
    # Emotions top 3
    emos = emotion_pipe(text)[0]
    top3 = sorted(emos, key=lambda x: x["score"], reverse=True)[:3]
    res["emotions"] = [{"label": e["label"], "score": float(e["score"])} for e in top3]
    # Hate vs Not Hate
    try:
        z = hate_pipe(text, candidate_labels=["hate", "not hate"])
        res["hate"] = {"label": z["labels"][0], "score": float(z["scores"][0])}
    except ValueError:
        res["hate"] = None
    # Translation
    if lang != "en":
        tr = translation_pipe(text, max_length=256)[0]["translation_text"]
        res["translation"] = tr
        summary_input = tr
    else:
        res["translation"] = text
        summary_input = text
    # Summarization dinámico
    tok = summarization_pipe.tokenizer
    ids = tok.encode(summary_input, return_tensors="pt")[0]
    max_len = max(5, min(60, len(ids) - 2))
    sm = summarization_pipe(summary_input, max_length=max_len, min_length=5)[0]["summary_text"]
    res["summary"] = sm
    return res

# 3) Cargar datos
input_path = "tweets_españoles_anotados_finales_id.json"
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)

lang = "es"  # 'el' para griego es español

# 4) Procesar en dos trozos: indices 0–499 y 500–999
ranges = [(0, 500), (500, 1000)]
for start, end in ranges:
    subset = data[start:end]
    total = len(subset)
    output_path = f"tweets_españoles_evaluados_{start+1}_{start+total}.json"
    
    for idx, item in enumerate(subset, start=1):
        print(f"Procesando chunk {start+1}-{end}, tweet {idx}/{total}")
        # tweet principal
        item["analysis"] = analyze_text(item.get("tweet", ""), lang)
        # todas las replies
        for r_idx, reply in enumerate(item.get("replies", []), start=1):
            reply["analysis"] = analyze_text(reply.get("reply", ""), lang)
    
    # guardar este chunk
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(subset, f, ensure_ascii=False, indent=2)
    print(f"Chunk {start+1}-{start+total} completado. Salvo en {output_path}\n")

# %%
# Requiere stanza: ejecuta esto solo una vez si no lo tienes
# !pip install stanza

import json
import stanza

# Descargar modelo en griego (solo la primera vez)
stanza.download("es")

# Cargar el pipeline de Stanza en griego
nlp = stanza.Pipeline("es", processors="tokenize,sentiment", use_gpu=True)

# Función para analizar sentimiento con Stanza
def analyze_with_stanza(text):
    if not text.strip():
        return {"sentiment": None}
    doc = nlp(text)
    sentiments = [{"text": s.text, "sentiment": s.sentiment} for s in doc.sentences]
    overall_sentiment = round(sum(s["sentiment"] for s in sentiments) / len(sentiments)) if sentiments else None
    return {"sentiment": overall_sentiment, "sentences": sentiments}

# Ruta del archivo de entrada
input_path = "spain/Completado/tweets_españoles_evaluados_completo.json"
# Cargar datos
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# Procesar por bloques: 0–499 y 500–999
ranges = [(0, 500), (500, 1000)]
for start, end in ranges:
    subset = data[start:end]
    total = len(subset)
    output_path = f"tweets_griegos_stanza_{start+1}_{start+total}.json"  # Nombre corregido

    for idx, item in enumerate(subset, start=1):
        print(f"Procesando bloque {start+1}-{end}, tweet {idx}/{total}")
        # Tweet principal
        item["analysis"] = analyze_with_stanza(item.get("tweet", ""))
        # Replies
        for reply in item.get("replies", []):
            reply["analysis"] = analyze_with_stanza(reply.get("reply", ""))

    # Guardar resultados
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(subset, f, ensure_ascii=False, indent=2)
    print(f"✅ Bloque {start+1}-{start+total} guardado como {output_path}")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-05-01 11:51:04 INFO: Downloaded file to /home/jupyter-lquijano/stanza_resources/resources.json
# 2025-05-01 11:51:04 INFO: Downloading default packages for language: es (Spanish) ...
# 2025-05-01 11:51:05 INFO: File exists: /home/jupyter-lquijano/stanza_resources/es/default.zip
# 2025-05-01 11:51:09 INFO: Finished downloading models and saved to /home/jupyter-lquijano/stanza_resources
# 2025-05-01 11:51:09 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-05-01 11:51:09 INFO: Downloaded file to /home/jupyter-lquijano/stanza_resources/resources.json
# 2025-05-01 11:51:09 WARNING: Language es package default expects mwt, which has been added
# 2025-05-01 11:51:09 INFO: Loading these models for language: es (Spanish):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | mwt       | combined        |
# | sentiment | tass2020_charlm |
# ===============================
#
# 2025-05-01 11:51:09 INFO: Using device: cuda
# 2025-05-01 11:51:09 INFO: Loading: tokenize
# 2025-05-01 11:51:09 INFO: Loading: mwt
# 2025-05-01 11:51:09 INFO: Loading: sentiment
# 2025-05-01 11:51:11 INFO: Done loading processors!
# Procesando bloque 1-500, tweet 1/500
# Procesando bloque 1-500, tweet 2/500
# Procesando bloque 1-500, tweet 3/500
# Procesando bloque 1-500, tweet 4/500
# Procesando bloque 1-500, tweet 5/500
# Procesando bloque 1-500, tweet 6/500
# Procesando bloque 1-500, tweet 7/500
# Procesando bloque 1-500, tweet 8/500
# Procesando bloque 1-500, tweet 9/500
# Procesando bloque 1-500, tweet 10/500
# Procesando bloque 1-500, tweet 11/500
# Procesando bloque 1-500, tweet 12/500
# Procesando bloque 1-500, tweet 13/500
# Procesando bloque 1-500, tweet 14/500
# Procesando bloque 1-500, tweet 15/500
# Procesando bloque 1-500, tweet 16/500
# Procesando bloque 1-500, tweet 17/500
# Procesando bloque 1-500, tweet 18/500
# Procesando bloque 1-500, tweet 19/500
# Procesando bloque 1-500, tweet 20/500
# Procesando bloque 1-500, tweet 21/500
# Procesando bloque 1-500, tweet 22/500
# Procesando bloque 1-500, tweet 23/500
# Procesando bloque 1-500, tweet 24/500
# Procesando bloque 1-500, tweet 25/500
# Procesando bloque 1-500, tweet 26/500
# Procesando bloque 1-500, tweet 27/500
# Procesando bloque 1-500, tweet 28/500
# Procesando bloque 1-500, tweet 29/500
# Procesando bloque 1-500, tweet 30/500
# Procesando bloque 1-500, tweet 31/500
# Procesando bloque 1-500, tweet 32/500
# Procesando bloque 1-500, tweet 33/500
# Procesando bloque 1-500, tweet 34/500
# Procesando bloque 1-500, tweet 35/500
# Procesando bloque 1-500, tweet 36/500
# Procesando bloque 1-500, tweet 37/500
# Procesando bloque 1-500, tweet 38/500
# Procesando bloque 1-500, tweet 39/500
# Procesando bloque 1-500, tweet 40/500
# Procesando bloque 1-500, tweet 41/500
# Procesando bloque 1-500, tweet 42/500
# Procesando bloque 1-500, tweet 43/500
# Procesando bloque 1-500, tweet 44/500
# Procesando bloque 1-500, tweet 45/500
# Procesando bloque 1-500, tweet 46/500
# Procesando bloque 1-500, tweet 47/500
# Procesando bloque 1-500, tweet 48/500
# Procesando bloque 1-500, tweet 49/500
# Procesando bloque 1-500, tweet 50/500
# Procesando bloque 1-500, tweet 51/500
# Procesando bloque 1-500, tweet 52/500
# Procesando bloque 1-500, tweet 53/500
# Procesando bloque 1-500, tweet 54/500
# Procesando bloque 1-500, tweet 55/500
# Procesando bloque 1-500, tweet 56/500
# Procesando bloque 1-500, tweet 57/500
# Procesando bloque 1-500, tweet 58/500
# Procesando bloque 1-500, tweet 59/500
# Procesando bloque 1-500, tweet 60/500
# Procesando bloque 1-500, tweet 61/500
# Procesando bloque 1-500, tweet 62/500
# Procesando bloque 1-500, tweet 63/500
# Procesando bloque 1-500, tweet 64/500
# Procesando bloque 1-500, tweet 65/500
# Procesando bloque 1-500, tweet 66/500
# Procesando bloque 1-500, tweet 67/500
# Procesando bloque 1-500, tweet 68/500
# Procesando bloque 1-500, tweet 69/500
# Procesando bloque 1-500, tweet 70/500
# Procesando bloque 1-500, tweet 71/500
# Procesando bloque 1-500, tweet 72/500
# Procesando bloque 1-500, tweet 73/500
# Procesando bloque 1-500, tweet 74/500
# Procesando bloque 1-500, tweet 75/500
# Procesando bloque 1-500, tweet 76/500
# Procesando bloque 1-500, tweet 77/500
# Procesando bloque 1-500, tweet 78/500
# Procesando bloque 1-500, tweet 79/500
# Procesando bloque 1-500, tweet 80/500
# Procesando bloque 1-500, tweet 81/500
# Procesando bloque 1-500, tweet 82/500
# Procesando bloque 1-500, tweet 83/500
# Procesando bloque 1-500, tweet 84/500
# Procesando bloque 1-500, tweet 85/500
# Procesando bloque 1-500, tweet 86/500
# Procesando bloque 1-500, tweet 87/500
# Procesando bloque 1-500, tweet 88/500
# Procesando bloque 1-500, tweet 89/500
# Procesando bloque 1-500, tweet 90/500
# Procesando bloque 1-500, tweet 91/500
# Procesando bloque 1-500, tweet 92/500
# Procesando bloque 1-500, tweet 93/500
# Procesando bloque 1-500, tweet 94/500
# Procesando bloque 1-500, tweet 95/500
# Procesando bloque 1-500, tweet 96/500
# Procesando bloque 1-500, tweet 97/500
# Procesando bloque 1-500, tweet 98/500
# Procesando bloque 1-500, tweet 99/500
# Procesando bloque 1-500, tweet 100/500
# Procesando bloque 1-500, tweet 101/500
# Procesando bloque 1-500, tweet 102/500
# Procesando bloque 1-500, tweet 103/500
# Procesando bloque 1-500, tweet 104/500
# Procesando bloque 1-500, tweet 105/500
# Procesando bloque 1-500, tweet 106/500
# Procesando bloque 1-500, tweet 107/500
# Procesando bloque 1-500, tweet 108/500
# Procesando bloque 1-500, tweet 109/500
# Procesando bloque 1-500, tweet 110/500
# Procesando bloque 1-500, tweet 111/500
# Procesando bloque 1-500, tweet 112/500
# Procesando bloque 1-500, tweet 113/500
# Procesando bloque 1-500, tweet 114/500
# Procesando bloque 1-500, tweet 115/500
# Procesando bloque 1-500, tweet 116/500
# Procesando bloque 1-500, tweet 117/500
# Procesando bloque 1-500, tweet 118/500
# Procesando bloque 1-500, tweet 119/500
# Procesando bloque 1-500, tweet 120/500
# Procesando bloque 1-500, tweet 121/500
# Procesando bloque 1-500, tweet 122/500
# Procesando bloque 1-500, tweet 123/500
# Procesando bloque 1-500, tweet 124/500
# Procesando bloque 1-500, tweet 125/500
# Procesando bloque 1-500, tweet 126/500
# Procesando bloque 1-500, tweet 127/500
# Procesando bloque 1-500, tweet 128/500
# Procesando bloque 1-500, tweet 129/500
# Procesando bloque 1-500, tweet 130/500
# Procesando bloque 1-500, tweet 131/500
# Procesando bloque 1-500, tweet 132/500
# Procesando bloque 1-500, tweet 133/500
# Procesando bloque 1-500, tweet 134/500
# Procesando bloque 1-500, tweet 135/500
# Procesando bloque 1-500, tweet 136/500
# Procesando bloque 1-500, tweet 137/500
# Procesando bloque 1-500, tweet 138/500
# Procesando bloque 1-500, tweet 139/500
# Procesando bloque 1-500, tweet 140/500
# Procesando bloque 1-500, tweet 141/500
# Procesando bloque 1-500, tweet 142/500
# Procesando bloque 1-500, tweet 143/500
# Procesando bloque 1-500, tweet 144/500
# Procesando bloque 1-500, tweet 145/500
# Procesando bloque 1-500, tweet 146/500
# Procesando bloque 1-500, tweet 147/500
# Procesando bloque 1-500, tweet 148/500
# Procesando bloque 1-500, tweet 149/500
# Procesando bloque 1-500, tweet 150/500
# Procesando bloque 1-500, tweet 151/500
# Procesando bloque 1-500, tweet 152/500
# Procesando bloque 1-500, tweet 153/500
# Procesando bloque 1-500, tweet 154/500
# Procesando bloque 1-500, tweet 155/500
# Procesando bloque 1-500, tweet 156/500
# Procesando bloque 1-500, tweet 157/500
# Procesando bloque 1-500, tweet 158/500
# Procesando bloque 1-500, tweet 159/500
# Procesando bloque 1-500, tweet 160/500
# Procesando bloque 1-500, tweet 161/500
# Procesando bloque 1-500, tweet 162/500
# Procesando bloque 1-500, tweet 163/500
# Procesando bloque 1-500, tweet 164/500
# Procesando bloque 1-500, tweet 165/500
# Procesando bloque 1-500, tweet 166/500
# Procesando bloque 1-500, tweet 167/500
# Procesando bloque 1-500, tweet 168/500
# Procesando bloque 1-500, tweet 169/500
# Procesando bloque 1-500, tweet 170/500
# Procesando bloque 1-500, tweet 171/500
# Procesando bloque 1-500, tweet 172/500
# Procesando bloque 1-500, tweet 173/500
# Procesando bloque 1-500, tweet 174/500
# Procesando bloque 1-500, tweet 175/500
# Procesando bloque 1-500, tweet 176/500
# Procesando bloque 1-500, tweet 177/500
# Procesando bloque 1-500, tweet 178/500
# Procesando bloque 1-500, tweet 179/500
# Procesando bloque 1-500, tweet 180/500
# Procesando bloque 1-500, tweet 181/500
# Procesando bloque 1-500, tweet 182/500
# Procesando bloque 1-500, tweet 183/500
# Procesando bloque 1-500, tweet 184/500
# Procesando bloque 1-500, tweet 185/500
# Procesando bloque 1-500, tweet 186/500
# Procesando bloque 1-500, tweet 187/500
# Procesando bloque 1-500, tweet 188/500
# Procesando bloque 1-500, tweet 189/500
# Procesando bloque 1-500, tweet 190/500
# Procesando bloque 1-500, tweet 191/500
# Procesando bloque 1-500, tweet 192/500
# Procesando bloque 1-500, tweet 193/500
# Procesando bloque 1-500, tweet 194/500
# Procesando bloque 1-500, tweet 195/500
# Procesando bloque 1-500, tweet 196/500
# Procesando bloque 1-500, tweet 197/500
# Procesando bloque 1-500, tweet 198/500
# Procesando bloque 1-500, tweet 199/500
# Procesando bloque 1-500, tweet 200/500
# Procesando bloque 1-500, tweet 201/500
# Procesando bloque 1-500, tweet 202/500
# Procesando bloque 1-500, tweet 203/500
# Procesando bloque 1-500, tweet 204/500
# Procesando bloque 1-500, tweet 205/500
# Procesando bloque 1-500, tweet 206/500
# Procesando bloque 1-500, tweet 207/500
# Procesando bloque 1-500, tweet 208/500
# Procesando bloque 1-500, tweet 209/500
# Procesando bloque 1-500, tweet 210/500
# Procesando bloque 1-500, tweet 211/500
# Procesando bloque 1-500, tweet 212/500
# Procesando bloque 1-500, tweet 213/500
# Procesando bloque 1-500, tweet 214/500
# Procesando bloque 1-500, tweet 215/500
# Procesando bloque 1-500, tweet 216/500
# Procesando bloque 1-500, tweet 217/500
# Procesando bloque 1-500, tweet 218/500
# Procesando bloque 1-500, tweet 219/500
# Procesando bloque 1-500, tweet 220/500
# Procesando bloque 1-500, tweet 221/500
# Procesando bloque 1-500, tweet 222/500
# Procesando bloque 1-500, tweet 223/500
# Procesando bloque 1-500, tweet 224/500
# Procesando bloque 1-500, tweet 225/500
# Procesando bloque 1-500, tweet 226/500
# Procesando bloque 1-500, tweet 227/500
# Procesando bloque 1-500, tweet 228/500
# Procesando bloque 1-500, tweet 229/500
# Procesando bloque 1-500, tweet 230/500
# Procesando bloque 1-500, tweet 231/500
# Procesando bloque 1-500, tweet 232/500
# Procesando bloque 1-500, tweet 233/500
# Procesando bloque 1-500, tweet 234/500
# Procesando bloque 1-500, tweet 235/500
# Procesando bloque 1-500, tweet 236/500
# Procesando bloque 1-500, tweet 237/500
# Procesando bloque 1-500, tweet 238/500
# Procesando bloque 1-500, tweet 239/500
# Procesando bloque 1-500, tweet 240/500
# Procesando bloque 1-500, tweet 241/500
# Procesando bloque 1-500, tweet 242/500
# Procesando bloque 1-500, tweet 243/500
# Procesando bloque 1-500, tweet 244/500
# Procesando bloque 1-500, tweet 245/500
# Procesando bloque 1-500, tweet 246/500
# Procesando bloque 1-500, tweet 247/500
# Procesando bloque 1-500, tweet 248/500
# Procesando bloque 1-500, tweet 249/500
# Procesando bloque 1-500, tweet 250/500
# Procesando bloque 1-500, tweet 251/500
# Procesando bloque 1-500, tweet 252/500
# Procesando bloque 1-500, tweet 253/500
# Procesando bloque 1-500, tweet 254/500
# Procesando bloque 1-500, tweet 255/500
# Procesando bloque 1-500, tweet 256/500
# Procesando bloque 1-500, tweet 257/500
# Procesando bloque 1-500, tweet 258/500
# Procesando bloque 1-500, tweet 259/500
# Procesando bloque 1-500, tweet 260/500
# Procesando bloque 1-500, tweet 261/500
# Procesando bloque 1-500, tweet 262/500
# Procesando bloque 1-500, tweet 263/500
# Procesando bloque 1-500, tweet 264/500
# Procesando bloque 1-500, tweet 265/500
# Procesando bloque 1-500, tweet 266/500
# Procesando bloque 1-500, tweet 267/500
# Procesando bloque 1-500, tweet 268/500
# Procesando bloque 1-500, tweet 269/500
# Procesando bloque 1-500, tweet 270/500
# Procesando bloque 1-500, tweet 271/500
# Procesando bloque 1-500, tweet 272/500
# Procesando bloque 1-500, tweet 273/500
# Procesando bloque 1-500, tweet 274/500
# Procesando bloque 1-500, tweet 275/500
# Procesando bloque 1-500, tweet 276/500
# Procesando bloque 1-500, tweet 277/500
# Procesando bloque 1-500, tweet 278/500
# Procesando bloque 1-500, tweet 279/500
# Procesando bloque 1-500, tweet 280/500
# Procesando bloque 1-500, tweet 281/500
# Procesando bloque 1-500, tweet 282/500
# Procesando bloque 1-500, tweet 283/500
# Procesando bloque 1-500, tweet 284/500
# Procesando bloque 1-500, tweet 285/500
# Procesando bloque 1-500, tweet 286/500
# Procesando bloque 1-500, tweet 287/500
# Procesando bloque 1-500, tweet 288/500
# Procesando bloque 1-500, tweet 289/500
# Procesando bloque 1-500, tweet 290/500
# Procesando bloque 1-500, tweet 291/500
# Procesando bloque 1-500, tweet 292/500
# Procesando bloque 1-500, tweet 293/500
# Procesando bloque 1-500, tweet 294/500
# Procesando bloque 1-500, tweet 295/500
# Procesando bloque 1-500, tweet 296/500
# Procesando bloque 1-500, tweet 297/500
# Procesando bloque 1-500, tweet 298/500
# Procesando bloque 1-500, tweet 299/500
# Procesando bloque 1-500, tweet 300/500
# Procesando bloque 1-500, tweet 301/500
# Procesando bloque 1-500, tweet 302/500
# Procesando bloque 1-500, tweet 303/500
# Procesando bloque 1-500, tweet 304/500
# Procesando bloque 1-500, tweet 305/500
# Procesando bloque 1-500, tweet 306/500
# Procesando bloque 1-500, tweet 307/500
# Procesando bloque 1-500, tweet 308/500
# Procesando bloque 1-500, tweet 309/500
# Procesando bloque 1-500, tweet 310/500
# Procesando bloque 1-500, tweet 311/500
# Procesando bloque 1-500, tweet 312/500
# Procesando bloque 1-500, tweet 313/500
# Procesando bloque 1-500, tweet 314/500
# Procesando bloque 1-500, tweet 315/500
# Procesando bloque 1-500, tweet 316/500
# Procesando bloque 1-500, tweet 317/500
# Procesando bloque 1-500, tweet 318/500
# Procesando bloque 1-500, tweet 319/500
# Procesando bloque 1-500, tweet 320/500
# Procesando bloque 1-500, tweet 321/500
# Procesando bloque 1-500, tweet 322/500
# Procesando bloque 1-500, tweet 323/500
# Procesando bloque 1-500, tweet 324/500
# Procesando bloque 1-500, tweet 325/500
# Procesando bloque 1-500, tweet 326/500
# Procesando bloque 1-500, tweet 327/500
# Procesando bloque 1-500, tweet 328/500
# Procesando bloque 1-500, tweet 329/500
# Procesando bloque 1-500, tweet 330/500
# Procesando bloque 1-500, tweet 331/500
# Procesando bloque 1-500, tweet 332/500
# Procesando bloque 1-500, tweet 333/500
# Procesando bloque 1-500, tweet 334/500
# Procesando bloque 1-500, tweet 335/500
# Procesando bloque 1-500, tweet 336/500
# Procesando bloque 1-500, tweet 337/500
# Procesando bloque 1-500, tweet 338/500
# Procesando bloque 1-500, tweet 339/500
# Procesando bloque 1-500, tweet 340/500
# Procesando bloque 1-500, tweet 341/500
# Procesando bloque 1-500, tweet 342/500
# Procesando bloque 1-500, tweet 343/500
# Procesando bloque 1-500, tweet 344/500
# Procesando bloque 1-500, tweet 345/500
# Procesando bloque 1-500, tweet 346/500
# Procesando bloque 1-500, tweet 347/500
# Procesando bloque 1-500, tweet 348/500
# Procesando bloque 1-500, tweet 349/500
# Procesando bloque 1-500, tweet 350/500
# Procesando bloque 1-500, tweet 351/500
# Procesando bloque 1-500, tweet 352/500
# Procesando bloque 1-500, tweet 353/500
# Procesando bloque 1-500, tweet 354/500
# Procesando bloque 1-500, tweet 355/500
# Procesando bloque 1-500, tweet 356/500
# Procesando bloque 1-500, tweet 357/500
# Procesando bloque 1-500, tweet 358/500
# Procesando bloque 1-500, tweet 359/500
# Procesando bloque 1-500, tweet 360/500
# Procesando bloque 1-500, tweet 361/500
# Procesando bloque 1-500, tweet 362/500
# Procesando bloque 1-500, tweet 363/500
# Procesando bloque 1-500, tweet 364/500
# Procesando bloque 1-500, tweet 365/500
# Procesando bloque 1-500, tweet 366/500
# Procesando bloque 1-500, tweet 367/500
# Procesando bloque 1-500, tweet 368/500
# Procesando bloque 1-500, tweet 369/500
# Procesando bloque 1-500, tweet 370/500
# Procesando bloque 1-500, tweet 371/500
# Procesando bloque 1-500, tweet 372/500
# Procesando bloque 1-500, tweet 373/500
# Procesando bloque 1-500, tweet 374/500
# Procesando bloque 1-500, tweet 375/500
# Procesando bloque 1-500, tweet 376/500
# Procesando bloque 1-500, tweet 377/500
# Procesando bloque 1-500, tweet 378/500
# Procesando bloque 1-500, tweet 379/500
# Procesando bloque 1-500, tweet 380/500
# Procesando bloque 1-500, tweet 381/500
# Procesando bloque 1-500, tweet 382/500
# Procesando bloque 1-500, tweet 383/500
# Procesando bloque 1-500, tweet 384/500
# Procesando bloque 1-500, tweet 385/500
# Procesando bloque 1-500, tweet 386/500
# Procesando bloque 1-500, tweet 387/500
# Procesando bloque 1-500, tweet 388/500
# Procesando bloque 1-500, tweet 389/500
# Procesando bloque 1-500, tweet 390/500
# Procesando bloque 1-500, tweet 391/500
# Procesando bloque 1-500, tweet 392/500
# Procesando bloque 1-500, tweet 393/500
# Procesando bloque 1-500, tweet 394/500
# Procesando bloque 1-500, tweet 395/500
# Procesando bloque 1-500, tweet 396/500
# Procesando bloque 1-500, tweet 397/500
# Procesando bloque 1-500, tweet 398/500
# Procesando bloque 1-500, tweet 399/500
# Procesando bloque 1-500, tweet 400/500
# Procesando bloque 1-500, tweet 401/500
# Procesando bloque 1-500, tweet 402/500
# Procesando bloque 1-500, tweet 403/500
# Procesando bloque 1-500, tweet 404/500
# Procesando bloque 1-500, tweet 405/500
# Procesando bloque 1-500, tweet 406/500
# Procesando bloque 1-500, tweet 407/500
# Procesando bloque 1-500, tweet 408/500
# Procesando bloque 1-500, tweet 409/500
# Procesando bloque 1-500, tweet 410/500
# Procesando bloque 1-500, tweet 411/500
# Procesando bloque 1-500, tweet 412/500
# Procesando bloque 1-500, tweet 413/500
# Procesando bloque 1-500, tweet 414/500
# Procesando bloque 1-500, tweet 415/500
# Procesando bloque 1-500, tweet 416/500
# Procesando bloque 1-500, tweet 417/500
# Procesando bloque 1-500, tweet 418/500
# Procesando bloque 1-500, tweet 419/500
# Procesando bloque 1-500, tweet 420/500
# Procesando bloque 1-500, tweet 421/500
# Procesando bloque 1-500, tweet 422/500
# Procesando bloque 1-500, tweet 423/500
# Procesando bloque 1-500, tweet 424/500
# Procesando bloque 1-500, tweet 425/500
# Procesando bloque 1-500, tweet 426/500
# Procesando bloque 1-500, tweet 427/500
# Procesando bloque 1-500, tweet 428/500
# Procesando bloque 1-500, tweet 429/500
# Procesando bloque 1-500, tweet 430/500
# Procesando bloque 1-500, tweet 431/500
# Procesando bloque 1-500, tweet 432/500
# Procesando bloque 1-500, tweet 433/500
# Procesando bloque 1-500, tweet 434/500
# Procesando bloque 1-500, tweet 435/500
# Procesando bloque 1-500, tweet 436/500
# Procesando bloque 1-500, tweet 437/500
# Procesando bloque 1-500, tweet 438/500
# Procesando bloque 1-500, tweet 439/500
# Procesando bloque 1-500, tweet 440/500
# Procesando bloque 1-500, tweet 441/500
# Procesando bloque 1-500, tweet 442/500
# Procesando bloque 1-500, tweet 443/500
# Procesando bloque 1-500, tweet 444/500
# Procesando bloque 1-500, tweet 445/500
# Procesando bloque 1-500, tweet 446/500
# Procesando bloque 1-500, tweet 447/500
# Procesando bloque 1-500, tweet 448/500
# Procesando bloque 1-500, tweet 449/500
# Procesando bloque 1-500, tweet 450/500
# Procesando bloque 1-500, tweet 451/500
# Procesando bloque 1-500, tweet 452/500
# Procesando bloque 1-500, tweet 453/500
# Procesando bloque 1-500, tweet 454/500
# Procesando bloque 1-500, tweet 455/500
# Procesando bloque 1-500, tweet 456/500
# Procesando bloque 1-500, tweet 457/500
# Procesando bloque 1-500, tweet 458/500
# Procesando bloque 1-500, tweet 459/500
# Procesando bloque 1-500, tweet 460/500
# Procesando bloque 1-500, tweet 461/500
# Procesando bloque 1-500, tweet 462/500
# Procesando bloque 1-500, tweet 463/500
# Procesando bloque 1-500, tweet 464/500
# Procesando bloque 1-500, tweet 465/500
# Procesando bloque 1-500, tweet 466/500
# Procesando bloque 1-500, tweet 467/500
# Procesando bloque 1-500, tweet 468/500
# Procesando bloque 1-500, tweet 469/500
# Procesando bloque 1-500, tweet 470/500
# Procesando bloque 1-500, tweet 471/500
# Procesando bloque 1-500, tweet 472/500
# Procesando bloque 1-500, tweet 473/500
# Procesando bloque 1-500, tweet 474/500
# Procesando bloque 1-500, tweet 475/500
# Procesando bloque 1-500, tweet 476/500
# Procesando bloque 1-500, tweet 477/500
# Procesando bloque 1-500, tweet 478/500
# Procesando bloque 1-500, tweet 479/500
# Procesando bloque 1-500, tweet 480/500
# Procesando bloque 1-500, tweet 481/500
# Procesando bloque 1-500, tweet 482/500
# Procesando bloque 1-500, tweet 483/500
# Procesando bloque 1-500, tweet 484/500
# Procesando bloque 1-500, tweet 485/500
# Procesando bloque 1-500, tweet 486/500
# Procesando bloque 1-500, tweet 487/500
# Procesando bloque 1-500, tweet 488/500
# Procesando bloque 1-500, tweet 489/500
# Procesando bloque 1-500, tweet 490/500
# Procesando bloque 1-500, tweet 491/500
# Procesando bloque 1-500, tweet 492/500
# Procesando bloque 1-500, tweet 493/500
# Procesando bloque 1-500, tweet 494/500
# Procesando bloque 1-500, tweet 495/500
# Procesando bloque 1-500, tweet 496/500
# Procesando bloque 1-500, tweet 497/500
# Procesando bloque 1-500, tweet 498/500
# Procesando bloque 1-500, tweet 499/500
# Procesando bloque 1-500, tweet 500/500
# ✅ Bloque 1-500 guardado como tweets_griegos_stanza_1_500.json
# Procesando bloque 501-1000, tweet 1/500
# Procesando bloque 501-1000, tweet 2/500
# Procesando bloque 501-1000, tweet 3/500
# Procesando bloque 501-1000, tweet 4/500
# Procesando bloque 501-1000, tweet 5/500
# Procesando bloque 501-1000, tweet 6/500
# Procesando bloque 501-1000, tweet 7/500
# Procesando bloque 501-1000, tweet 8/500
# Procesando bloque 501-1000, tweet 9/500
# Procesando bloque 501-1000, tweet 10/500
# Procesando bloque 501-1000, tweet 11/500
# Procesando bloque 501-1000, tweet 12/500
# Procesando bloque 501-1000, tweet 13/500
# Procesando bloque 501-1000, tweet 14/500
# Procesando bloque 501-1000, tweet 15/500
# Procesando bloque 501-1000, tweet 16/500
# Procesando bloque 501-1000, tweet 17/500
# Procesando bloque 501-1000, tweet 18/500
# Procesando bloque 501-1000, tweet 19/500
# Procesando bloque 501-1000, tweet 20/500
# Procesando bloque 501-1000, tweet 21/500
# Procesando bloque 501-1000, tweet 22/500
# Procesando bloque 501-1000, tweet 23/500
# Procesando bloque 501-1000, tweet 24/500
# Procesando bloque 501-1000, tweet 25/500
# Procesando bloque 501-1000, tweet 26/500
# Procesando bloque 501-1000, tweet 27/500
# Procesando bloque 501-1000, tweet 28/500
# Procesando bloque 501-1000, tweet 29/500
# Procesando bloque 501-1000, tweet 30/500
# Procesando bloque 501-1000, tweet 31/500
# Procesando bloque 501-1000, tweet 32/500
# Procesando bloque 501-1000, tweet 33/500
# Procesando bloque 501-1000, tweet 34/500
# Procesando bloque 501-1000, tweet 35/500
# Procesando bloque 501-1000, tweet 36/500
# Procesando bloque 501-1000, tweet 37/500
# Procesando bloque 501-1000, tweet 38/500
# Procesando bloque 501-1000, tweet 39/500
# Procesando bloque 501-1000, tweet 40/500
# Procesando bloque 501-1000, tweet 41/500
# Procesando bloque 501-1000, tweet 42/500
# Procesando bloque 501-1000, tweet 43/500
# Procesando bloque 501-1000, tweet 44/500
# Procesando bloque 501-1000, tweet 45/500
# Procesando bloque 501-1000, tweet 46/500
# Procesando bloque 501-1000, tweet 47/500
# Procesando bloque 501-1000, tweet 48/500
# Procesando bloque 501-1000, tweet 49/500
# Procesando bloque 501-1000, tweet 50/500
# Procesando bloque 501-1000, tweet 51/500
# Procesando bloque 501-1000, tweet 52/500
# Procesando bloque 501-1000, tweet 53/500
# Procesando bloque 501-1000, tweet 54/500
# Procesando bloque 501-1000, tweet 55/500
# Procesando bloque 501-1000, tweet 56/500
# Procesando bloque 501-1000, tweet 57/500
# Procesando bloque 501-1000, tweet 58/500
# Procesando bloque 501-1000, tweet 59/500
# Procesando bloque 501-1000, tweet 60/500
# Procesando bloque 501-1000, tweet 61/500
# Procesando bloque 501-1000, tweet 62/500
# Procesando bloque 501-1000, tweet 63/500
# Procesando bloque 501-1000, tweet 64/500
# Procesando bloque 501-1000, tweet 65/500
# Procesando bloque 501-1000, tweet 66/500
# Procesando bloque 501-1000, tweet 67/500
# Procesando bloque 501-1000, tweet 68/500
# Procesando bloque 501-1000, tweet 69/500
# Procesando bloque 501-1000, tweet 70/500
# Procesando bloque 501-1000, tweet 71/500
# Procesando bloque 501-1000, tweet 72/500
# Procesando bloque 501-1000, tweet 73/500
# Procesando bloque 501-1000, tweet 74/500
# Procesando bloque 501-1000, tweet 75/500
# Procesando bloque 501-1000, tweet 76/500
# Procesando bloque 501-1000, tweet 77/500
# Procesando bloque 501-1000, tweet 78/500
# Procesando bloque 501-1000, tweet 79/500
# Procesando bloque 501-1000, tweet 80/500
# Procesando bloque 501-1000, tweet 81/500
# Procesando bloque 501-1000, tweet 82/500
# Procesando bloque 501-1000, tweet 83/500
# Procesando bloque 501-1000, tweet 84/500
# Procesando bloque 501-1000, tweet 85/500
# Procesando bloque 501-1000, tweet 86/500
# Procesando bloque 501-1000, tweet 87/500
# Procesando bloque 501-1000, tweet 88/500
# Procesando bloque 501-1000, tweet 89/500
# Procesando bloque 501-1000, tweet 90/500
# Procesando bloque 501-1000, tweet 91/500
# Procesando bloque 501-1000, tweet 92/500
# Procesando bloque 501-1000, tweet 93/500
# Procesando bloque 501-1000, tweet 94/500
# Procesando bloque 501-1000, tweet 95/500
# Procesando bloque 501-1000, tweet 96/500
# Procesando bloque 501-1000, tweet 97/500
# Procesando bloque 501-1000, tweet 98/500
# Procesando bloque 501-1000, tweet 99/500
# Procesando bloque 501-1000, tweet 100/500
# Procesando bloque 501-1000, tweet 101/500
# Procesando bloque 501-1000, tweet 102/500
# Procesando bloque 501-1000, tweet 103/500
# Procesando bloque 501-1000, tweet 104/500
# Procesando bloque 501-1000, tweet 105/500
# Procesando bloque 501-1000, tweet 106/500
# Procesando bloque 501-1000, tweet 107/500
# Procesando bloque 501-1000, tweet 108/500
# Procesando bloque 501-1000, tweet 109/500
# Procesando bloque 501-1000, tweet 110/500
# Procesando bloque 501-1000, tweet 111/500
# Procesando bloque 501-1000, tweet 112/500
# Procesando bloque 501-1000, tweet 113/500
# Procesando bloque 501-1000, tweet 114/500
# Procesando bloque 501-1000, tweet 115/500
# Procesando bloque 501-1000, tweet 116/500
# Procesando bloque 501-1000, tweet 117/500
# Procesando bloque 501-1000, tweet 118/500
# Procesando bloque 501-1000, tweet 119/500
# Procesando bloque 501-1000, tweet 120/500
# Procesando bloque 501-1000, tweet 121/500
# Procesando bloque 501-1000, tweet 122/500
# Procesando bloque 501-1000, tweet 123/500
# Procesando bloque 501-1000, tweet 124/500
# Procesando bloque 501-1000, tweet 125/500
# Procesando bloque 501-1000, tweet 126/500
# Procesando bloque 501-1000, tweet 127/500
# Procesando bloque 501-1000, tweet 128/500
# Procesando bloque 501-1000, tweet 129/500
# Procesando bloque 501-1000, tweet 130/500
# Procesando bloque 501-1000, tweet 131/500
# Procesando bloque 501-1000, tweet 132/500
# Procesando bloque 501-1000, tweet 133/500
# Procesando bloque 501-1000, tweet 134/500
# Procesando bloque 501-1000, tweet 135/500
# Procesando bloque 501-1000, tweet 136/500
# Procesando bloque 501-1000, tweet 137/500
# Procesando bloque 501-1000, tweet 138/500
# Procesando bloque 501-1000, tweet 139/500
# Procesando bloque 501-1000, tweet 140/500
# Procesando bloque 501-1000, tweet 141/500
# Procesando bloque 501-1000, tweet 142/500
# Procesando bloque 501-1000, tweet 143/500
# Procesando bloque 501-1000, tweet 144/500
# Procesando bloque 501-1000, tweet 145/500
# Procesando bloque 501-1000, tweet 146/500
# Procesando bloque 501-1000, tweet 147/500
# Procesando bloque 501-1000, tweet 148/500
# Procesando bloque 501-1000, tweet 149/500
# Procesando bloque 501-1000, tweet 150/500
# Procesando bloque 501-1000, tweet 151/500
# Procesando bloque 501-1000, tweet 152/500
# Procesando bloque 501-1000, tweet 153/500
# Procesando bloque 501-1000, tweet 154/500
# Procesando bloque 501-1000, tweet 155/500
# Procesando bloque 501-1000, tweet 156/500
# Procesando bloque 501-1000, tweet 157/500
# Procesando bloque 501-1000, tweet 158/500
# Procesando bloque 501-1000, tweet 159/500
# Procesando bloque 501-1000, tweet 160/500
# Procesando bloque 501-1000, tweet 161/500
# Procesando bloque 501-1000, tweet 162/500
# Procesando bloque 501-1000, tweet 163/500
# Procesando bloque 501-1000, tweet 164/500
# Procesando bloque 501-1000, tweet 165/500
# Procesando bloque 501-1000, tweet 166/500
# Procesando bloque 501-1000, tweet 167/500
# Procesando bloque 501-1000, tweet 168/500
# Procesando bloque 501-1000, tweet 169/500
# Procesando bloque 501-1000, tweet 170/500
# Procesando bloque 501-1000, tweet 171/500
# Procesando bloque 501-1000, tweet 172/500
# Procesando bloque 501-1000, tweet 173/500
# Procesando bloque 501-1000, tweet 174/500
# Procesando bloque 501-1000, tweet 175/500
# Procesando bloque 501-1000, tweet 176/500
# Procesando bloque 501-1000, tweet 177/500
# Procesando bloque 501-1000, tweet 178/500
# Procesando bloque 501-1000, tweet 179/500
# Procesando bloque 501-1000, tweet 180/500
# Procesando bloque 501-1000, tweet 181/500
# Procesando bloque 501-1000, tweet 182/500
# Procesando bloque 501-1000, tweet 183/500
# Procesando bloque 501-1000, tweet 184/500
# Procesando bloque 501-1000, tweet 185/500
# Procesando bloque 501-1000, tweet 186/500
# Procesando bloque 501-1000, tweet 187/500
# Procesando bloque 501-1000, tweet 188/500
# Procesando bloque 501-1000, tweet 189/500
# Procesando bloque 501-1000, tweet 190/500
# Procesando bloque 501-1000, tweet 191/500
# Procesando bloque 501-1000, tweet 192/500
# Procesando bloque 501-1000, tweet 193/500
# Procesando bloque 501-1000, tweet 194/500
# Procesando bloque 501-1000, tweet 195/500
# Procesando bloque 501-1000, tweet 196/500
# Procesando bloque 501-1000, tweet 197/500
# Procesando bloque 501-1000, tweet 198/500
# Procesando bloque 501-1000, tweet 199/500
# Procesando bloque 501-1000, tweet 200/500
# Procesando bloque 501-1000, tweet 201/500
# Procesando bloque 501-1000, tweet 202/500
# Procesando bloque 501-1000, tweet 203/500
# Procesando bloque 501-1000, tweet 204/500
# Procesando bloque 501-1000, tweet 205/500
# Procesando bloque 501-1000, tweet 206/500
# Procesando bloque 501-1000, tweet 207/500
# Procesando bloque 501-1000, tweet 208/500
# Procesando bloque 501-1000, tweet 209/500
# Procesando bloque 501-1000, tweet 210/500
# Procesando bloque 501-1000, tweet 211/500
# Procesando bloque 501-1000, tweet 212/500
# Procesando bloque 501-1000, tweet 213/500
# Procesando bloque 501-1000, tweet 214/500
# Procesando bloque 501-1000, tweet 215/500
# Procesando bloque 501-1000, tweet 216/500
# Procesando bloque 501-1000, tweet 217/500
# Procesando bloque 501-1000, tweet 218/500
# Procesando bloque 501-1000, tweet 219/500
# Procesando bloque 501-1000, tweet 220/500
# Procesando bloque 501-1000, tweet 221/500
# Procesando bloque 501-1000, tweet 222/500
# Procesando bloque 501-1000, tweet 223/500
# Procesando bloque 501-1000, tweet 224/500
# Procesando bloque 501-1000, tweet 225/500
# Procesando bloque 501-1000, tweet 226/500
# Procesando bloque 501-1000, tweet 227/500
# Procesando bloque 501-1000, tweet 228/500
# Procesando bloque 501-1000, tweet 229/500
# Procesando bloque 501-1000, tweet 230/500
# Procesando bloque 501-1000, tweet 231/500
# Procesando bloque 501-1000, tweet 232/500
# Procesando bloque 501-1000, tweet 233/500
# Procesando bloque 501-1000, tweet 234/500
# Procesando bloque 501-1000, tweet 235/500
# Procesando bloque 501-1000, tweet 236/500
# Procesando bloque 501-1000, tweet 237/500
# Procesando bloque 501-1000, tweet 238/500
# Procesando bloque 501-1000, tweet 239/500
# Procesando bloque 501-1000, tweet 240/500
# Procesando bloque 501-1000, tweet 241/500
# Procesando bloque 501-1000, tweet 242/500
# Procesando bloque 501-1000, tweet 243/500
# Procesando bloque 501-1000, tweet 244/500
# Procesando bloque 501-1000, tweet 245/500
# Procesando bloque 501-1000, tweet 246/500
# Procesando bloque 501-1000, tweet 247/500
# Procesando bloque 501-1000, tweet 248/500
# Procesando bloque 501-1000, tweet 249/500
# Procesando bloque 501-1000, tweet 250/500
# Procesando bloque 501-1000, tweet 251/500
# Procesando bloque 501-1000, tweet 252/500
# Procesando bloque 501-1000, tweet 253/500
# Procesando bloque 501-1000, tweet 254/500
# Procesando bloque 501-1000, tweet 255/500
# Procesando bloque 501-1000, tweet 256/500
# Procesando bloque 501-1000, tweet 257/500
# Procesando bloque 501-1000, tweet 258/500
# Procesando bloque 501-1000, tweet 259/500
# Procesando bloque 501-1000, tweet 260/500
# Procesando bloque 501-1000, tweet 261/500
# Procesando bloque 501-1000, tweet 262/500
# Procesando bloque 501-1000, tweet 263/500
# Procesando bloque 501-1000, tweet 264/500
# Procesando bloque 501-1000, tweet 265/500
# Procesando bloque 501-1000, tweet 266/500
# Procesando bloque 501-1000, tweet 267/500
# Procesando bloque 501-1000, tweet 268/500
# Procesando bloque 501-1000, tweet 269/500
# Procesando bloque 501-1000, tweet 270/500
# Procesando bloque 501-1000, tweet 271/500
# Procesando bloque 501-1000, tweet 272/500
# Procesando bloque 501-1000, tweet 273/500
# Procesando bloque 501-1000, tweet 274/500
# Procesando bloque 501-1000, tweet 275/500
# Procesando bloque 501-1000, tweet 276/500
# Procesando bloque 501-1000, tweet 277/500
# Procesando bloque 501-1000, tweet 278/500
# Procesando bloque 501-1000, tweet 279/500
# Procesando bloque 501-1000, tweet 280/500
# Procesando bloque 501-1000, tweet 281/500
# Procesando bloque 501-1000, tweet 282/500
# Procesando bloque 501-1000, tweet 283/500
# Procesando bloque 501-1000, tweet 284/500
# Procesando bloque 501-1000, tweet 285/500
# Procesando bloque 501-1000, tweet 286/500
# Procesando bloque 501-1000, tweet 287/500
# Procesando bloque 501-1000, tweet 288/500
# Procesando bloque 501-1000, tweet 289/500
# Procesando bloque 501-1000, tweet 290/500
# Procesando bloque 501-1000, tweet 291/500
# Procesando bloque 501-1000, tweet 292/500
# Procesando bloque 501-1000, tweet 293/500
# Procesando bloque 501-1000, tweet 294/500
# Procesando bloque 501-1000, tweet 295/500
# Procesando bloque 501-1000, tweet 296/500
# Procesando bloque 501-1000, tweet 297/500
# Procesando bloque 501-1000, tweet 298/500
# Procesando bloque 501-1000, tweet 299/500
# Procesando bloque 501-1000, tweet 300/500
# Procesando bloque 501-1000, tweet 301/500
# Procesando bloque 501-1000, tweet 302/500
# Procesando bloque 501-1000, tweet 303/500
# Procesando bloque 501-1000, tweet 304/500
# Procesando bloque 501-1000, tweet 305/500
# Procesando bloque 501-1000, tweet 306/500
# Procesando bloque 501-1000, tweet 307/500
# Procesando bloque 501-1000, tweet 308/500
# Procesando bloque 501-1000, tweet 309/500
# Procesando bloque 501-1000, tweet 310/500
# Procesando bloque 501-1000, tweet 311/500
# Procesando bloque 501-1000, tweet 312/500
# Procesando bloque 501-1000, tweet 313/500
# Procesando bloque 501-1000, tweet 314/500
# Procesando bloque 501-1000, tweet 315/500
# Procesando bloque 501-1000, tweet 316/500
# Procesando bloque 501-1000, tweet 317/500
# Procesando bloque 501-1000, tweet 318/500
# Procesando bloque 501-1000, tweet 319/500
# Procesando bloque 501-1000, tweet 320/500
# Procesando bloque 501-1000, tweet 321/500
# Procesando bloque 501-1000, tweet 322/500
# Procesando bloque 501-1000, tweet 323/500
# Procesando bloque 501-1000, tweet 324/500
# Procesando bloque 501-1000, tweet 325/500
# Procesando bloque 501-1000, tweet 326/500
# Procesando bloque 501-1000, tweet 327/500
# Procesando bloque 501-1000, tweet 328/500
# Procesando bloque 501-1000, tweet 329/500
# Procesando bloque 501-1000, tweet 330/500
# Procesando bloque 501-1000, tweet 331/500
# Procesando bloque 501-1000, tweet 332/500
# Procesando bloque 501-1000, tweet 333/500
# Procesando bloque 501-1000, tweet 334/500
# Procesando bloque 501-1000, tweet 335/500
# Procesando bloque 501-1000, tweet 336/500
# Procesando bloque 501-1000, tweet 337/500
# Procesando bloque 501-1000, tweet 338/500
# Procesando bloque 501-1000, tweet 339/500
# Procesando bloque 501-1000, tweet 340/500
# Procesando bloque 501-1000, tweet 341/500
# Procesando bloque 501-1000, tweet 342/500
# Procesando bloque 501-1000, tweet 343/500
# Procesando bloque 501-1000, tweet 344/500
# Procesando bloque 501-1000, tweet 345/500
# Procesando bloque 501-1000, tweet 346/500
# Procesando bloque 501-1000, tweet 347/500
# Procesando bloque 501-1000, tweet 348/500
# Procesando bloque 501-1000, tweet 349/500
# Procesando bloque 501-1000, tweet 350/500
# Procesando bloque 501-1000, tweet 351/500
# Procesando bloque 501-1000, tweet 352/500
# Procesando bloque 501-1000, tweet 353/500
# Procesando bloque 501-1000, tweet 354/500
# Procesando bloque 501-1000, tweet 355/500
# Procesando bloque 501-1000, tweet 356/500
# Procesando bloque 501-1000, tweet 357/500
# Procesando bloque 501-1000, tweet 358/500
# Procesando bloque 501-1000, tweet 359/500
# Procesando bloque 501-1000, tweet 360/500
# Procesando bloque 501-1000, tweet 361/500
# Procesando bloque 501-1000, tweet 362/500
# Procesando bloque 501-1000, tweet 363/500
# Procesando bloque 501-1000, tweet 364/500
# Procesando bloque 501-1000, tweet 365/500
# Procesando bloque 501-1000, tweet 366/500
# Procesando bloque 501-1000, tweet 367/500
# Procesando bloque 501-1000, tweet 368/500
# Procesando bloque 501-1000, tweet 369/500
# Procesando bloque 501-1000, tweet 370/500
# Procesando bloque 501-1000, tweet 371/500
# Procesando bloque 501-1000, tweet 372/500
# Procesando bloque 501-1000, tweet 373/500
# Procesando bloque 501-1000, tweet 374/500
# Procesando bloque 501-1000, tweet 375/500
# Procesando bloque 501-1000, tweet 376/500
# Procesando bloque 501-1000, tweet 377/500
# Procesando bloque 501-1000, tweet 378/500
# Procesando bloque 501-1000, tweet 379/500
# Procesando bloque 501-1000, tweet 380/500
# Procesando bloque 501-1000, tweet 381/500
# Procesando bloque 501-1000, tweet 382/500
# Procesando bloque 501-1000, tweet 383/500
# Procesando bloque 501-1000, tweet 384/500
# Procesando bloque 501-1000, tweet 385/500
# Procesando bloque 501-1000, tweet 386/500
# Procesando bloque 501-1000, tweet 387/500
# Procesando bloque 501-1000, tweet 388/500
# Procesando bloque 501-1000, tweet 389/500
# Procesando bloque 501-1000, tweet 390/500
# Procesando bloque 501-1000, tweet 391/500
# Procesando bloque 501-1000, tweet 392/500
# Procesando bloque 501-1000, tweet 393/500
# Procesando bloque 501-1000, tweet 394/500
# Procesando bloque 501-1000, tweet 395/500
# Procesando bloque 501-1000, tweet 396/500
# Procesando bloque 501-1000, tweet 397/500
# Procesando bloque 501-1000, tweet 398/500
# Procesando bloque 501-1000, tweet 399/500
# Procesando bloque 501-1000, tweet 400/500
# Procesando bloque 501-1000, tweet 401/500
# Procesando bloque 501-1000, tweet 402/500
# Procesando bloque 501-1000, tweet 403/500
# Procesando bloque 501-1000, tweet 404/500
# Procesando bloque 501-1000, tweet 405/500
# Procesando bloque 501-1000, tweet 406/500
# Procesando bloque 501-1000, tweet 407/500
# Procesando bloque 501-1000, tweet 408/500
# Procesando bloque 501-1000, tweet 409/500
# Procesando bloque 501-1000, tweet 410/500
# Procesando bloque 501-1000, tweet 411/500
# Procesando bloque 501-1000, tweet 412/500
# Procesando bloque 501-1000, tweet 413/500
# Procesando bloque 501-1000, tweet 414/500
# Procesando bloque 501-1000, tweet 415/500
# Procesando bloque 501-1000, tweet 416/500
# Procesando bloque 501-1000, tweet 417/500
# Procesando bloque 501-1000, tweet 418/500
# Procesando bloque 501-1000, tweet 419/500
# Procesando bloque 501-1000, tweet 420/500
# Procesando bloque 501-1000, tweet 421/500
# Procesando bloque 501-1000, tweet 422/500
# Procesando bloque 501-1000, tweet 423/500
# Procesando bloque 501-1000, tweet 424/500
# Procesando bloque 501-1000, tweet 425/500
# Procesando bloque 501-1000, tweet 426/500
# Procesando bloque 501-1000, tweet 427/500
# Procesando bloque 501-1000, tweet 428/500
# Procesando bloque 501-1000, tweet 429/500
# Procesando bloque 501-1000, tweet 430/500
# Procesando bloque 501-1000, tweet 431/500
# Procesando bloque 501-1000, tweet 432/500
# Procesando bloque 501-1000, tweet 433/500
# Procesando bloque 501-1000, tweet 434/500
# Procesando bloque 501-1000, tweet 435/500
# Procesando bloque 501-1000, tweet 436/500
# Procesando bloque 501-1000, tweet 437/500
# Procesando bloque 501-1000, tweet 438/500
# Procesando bloque 501-1000, tweet 439/500
# Procesando bloque 501-1000, tweet 440/500
# Procesando bloque 501-1000, tweet 441/500
# Procesando bloque 501-1000, tweet 442/500
# Procesando bloque 501-1000, tweet 443/500
# Procesando bloque 501-1000, tweet 444/500
# Procesando bloque 501-1000, tweet 445/500
# Procesando bloque 501-1000, tweet 446/500
# Procesando bloque 501-1000, tweet 447/500
# Procesando bloque 501-1000, tweet 448/500
# Procesando bloque 501-1000, tweet 449/500
# Procesando bloque 501-1000, tweet 450/500
# Procesando bloque 501-1000, tweet 451/500
# Procesando bloque 501-1000, tweet 452/500
# Procesando bloque 501-1000, tweet 453/500
# Procesando bloque 501-1000, tweet 454/500
# Procesando bloque 501-1000, tweet 455/500
# Procesando bloque 501-1000, tweet 456/500
# Procesando bloque 501-1000, tweet 457/500
# Procesando bloque 501-1000, tweet 458/500
# Procesando bloque 501-1000, tweet 459/500
# Procesando bloque 501-1000, tweet 460/500
# Procesando bloque 501-1000, tweet 461/500
# Procesando bloque 501-1000, tweet 462/500
# Procesando bloque 501-1000, tweet 463/500
# Procesando bloque 501-1000, tweet 464/500
# Procesando bloque 501-1000, tweet 465/500
# Procesando bloque 501-1000, tweet 466/500
# Procesando bloque 501-1000, tweet 467/500
# Procesando bloque 501-1000, tweet 468/500
# Procesando bloque 501-1000, tweet 469/500
# Procesando bloque 501-1000, tweet 470/500
# Procesando bloque 501-1000, tweet 471/500
# Procesando bloque 501-1000, tweet 472/500
# Procesando bloque 501-1000, tweet 473/500
# Procesando bloque 501-1000, tweet 474/500
# Procesando bloque 501-1000, tweet 475/500
# Procesando bloque 501-1000, tweet 476/500
# Procesando bloque 501-1000, tweet 477/500
# Procesando bloque 501-1000, tweet 478/500
# Procesando bloque 501-1000, tweet 479/500
# Procesando bloque 501-1000, tweet 480/500
# Procesando bloque 501-1000, tweet 481/500
# Procesando bloque 501-1000, tweet 482/500
# Procesando bloque 501-1000, tweet 483/500
# Procesando bloque 501-1000, tweet 484/500
# Procesando bloque 501-1000, tweet 485/500
# Procesando bloque 501-1000, tweet 486/500
# Procesando bloque 501-1000, tweet 487/500
# Procesando bloque 501-1000, tweet 488/500
# Procesando bloque 501-1000, tweet 489/500
# Procesando bloque 501-1000, tweet 490/500
# Procesando bloque 501-1000, tweet 491/500
# Procesando bloque 501-1000, tweet 492/500
# Procesando bloque 501-1000, tweet 493/500
# Procesando bloque 501-1000, tweet 494/500
# Procesando bloque 501-1000, tweet 495/500
# Procesando bloque 501-1000, tweet 496/500
# Procesando bloque 501-1000, tweet 497/500
# Procesando bloque 501-1000, tweet 498/500
# Procesando bloque 501-1000, tweet 499/500
# Procesando bloque 501-1000, tweet 500/500
# ✅ Bloque 501-1000 guardado como tweets_griegos_stanza_501_1000.json

# %%
# !pip install numpy==1.26.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 11.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
#   WARNING: The script f2py is installed in '/home/jupyter-lquijano/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed numpy-1.26.4

# %%
pip install numpy==1.26.4
