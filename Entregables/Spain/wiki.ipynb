# %%
# !pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in ./.local/lib/python3.12/site-packages (2.2.3)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in ./.local/lib/python3.12/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
import datetime
import pandas as pd
import requests
import time

# Parámetros
INPUT_JSON     = 'spain/users_españoles.json'
OUTPUT_XLSX    = 'politicos_españoles.xlsx'
REFERENCE_DATE = datetime.date(2025, 4, 20)
SPARQL_URL     = 'https://query.wikidata.org/sparql'
HEADERS        = {
    'Accept': 'application/json',
    'User-Agent': 'TarjetasVisitaScript/1.0 (tu_email@dominio.com)'
}

# Carga de nombres
with open(INPUT_JSON, encoding='utf-8') as f:
    items = json.load(f)
names = [item['name'] for item in items]

def fetch_data_for(name, max_retries=3):
    q = f"""
    SELECT ?dob ?genderLabel ?partyLabel WHERE {{
      {{ ?person rdfs:label "{name}"@el }} 
      UNION 
      {{ ?person rdfs:label "{name}"@en }}
      # Solo humanos:
      # ?person wdt:P31 wd:Q5.
      # (Opcional) Solo ciudadanos de Grecia:
      # ?person wdt:P27 wd:Q41.
      OPTIONAL {{ ?person wdt:P569 ?dob. }}
      OPTIONAL {{ ?person wdt:P21  ?gender. }}
      OPTIONAL {{ ?person wdt:P102 ?party. }}
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "es,en". }}
    }}
    """
    for intento in range(1, max_retries+1):
        res = requests.post(SPARQL_URL, data={'query': q}, headers=HEADERS)
        if res.status_code == 200:
            return res.json()['results']['bindings']
        elif res.status_code == 429:
            wait = 2 ** (intento - 1)
            print(f"  ↻ [{name}] 429, reintento en {wait}s…")
            time.sleep(wait)
        else:
            res.raise_for_status()
    print(f"  ✗ [{name}] Falló tras {max_retries} intentos")
    return []

rows = []
total = len(names)
for idx, name in enumerate(names, start=1):
    print(f"[{idx}/{total}] Procesando «{name}»…")
    recs = fetch_data_for(name)
    time.sleep(1)

    if recs:
        rec = recs[0]
        # Fecha de nacimiento → edad
        dob_str = rec.get('dob', {}).get('value')
        dob = datetime.datetime.fromisoformat(dob_str).date() if dob_str else None
        if dob:
            age = (
                REFERENCE_DATE.year - dob.year
                - ((REFERENCE_DATE.month, REFERENCE_DATE.day) < (dob.month, dob.day))
            )
        else:
            age = None

        # Género: primero mostramos raw, luego lo mapeamos
        g_raw = rec.get('genderLabel', {}).get('value', '')
        g_text = g_raw.lower()
        print(f"    → genderLabel crudo: {g_raw}")
        if any(k in g_text for k in ['male', 'masculino', 'hombre']):
            gender = 'masculino'
        elif any(k in g_text for k in ['female', 'femenino', 'mujer']):
            gender = 'femenino'
        else:
            gender = ''

        # Partido
        party = rec.get('partyLabel', {}).get('value', '')

        print(f"  ✓ edad: {age or 'N/A'}, género: {gender or 'N/A'}, partido: {party or 'N/A'}")
    else:
        age = None
        gender = ''
        party = ''
        print("  – Sin datos obtenidos")

    rows.append({
        'name':   name,
        'age':    age,
        'gender': gender,
        'party':  party
    })

# Exportar a Excel
df = pd.DataFrame(rows)
df.to_excel(OUTPUT_XLSX, index=False)
print(f"\n✅ Archivo generado: {OUTPUT_XLSX}")
# Out:
# [1/172] Procesando «Gloria Elizo»…
#   – Sin datos obtenidos
# [2/172] Procesando «Andrés Lorite»…
#   – Sin datos obtenidos
# [3/172] Procesando «Inés Sabanés»…
#   – Sin datos obtenidos
# [4/172] Procesando «José Alcaraz Martos»…
#   – Sin datos obtenidos
# [5/172] Procesando «Marisa Saavedra»…
#   – Sin datos obtenidos
# [6/172] Procesando «Daniel Senderos/»…
#   – Sin datos obtenidos
# [7/172] Procesando «Jaume Asens»…
#   – Sin datos obtenidos
# [8/172] Procesando «Marta Martín Llaguno»…
#   – Sin datos obtenidos
# [9/172] Procesando «Diego Gago Bugarín»…
#   – Sin datos obtenidos
# [10/172] Procesando «Miguel Gutiérrez»…
#   – Sin datos obtenidos
# [11/172] Procesando «Rosa Romero»…
#   – Sin datos obtenidos
# [12/172] Procesando «Juan Luis Soto Buril»…
#   – Sin datos obtenidos
# [13/172] Procesando «Pilar Cancela/»…
#   – Sin datos obtenidos
# [14/172] Procesando «Néstor Rego»…
#   – Sin datos obtenidos
# [15/172] Procesando «Pedro Sánchez»…
#   – Sin datos obtenidos
# [16/172] Procesando «Laura Borràs»…
#   – Sin datos obtenidos
# [17/172] Procesando «Héctor Gómez»…
#   – Sin datos obtenidos
# [18/172] Procesando «mjesus moro almaraz»…
#   – Sin datos obtenidos
# [19/172] Procesando «Ines Granollers»…
#   – Sin datos obtenidos
# [20/172] Procesando «Ricardo Chamorro Delmo»…
#   – Sin datos obtenidos
# [21/172] Procesando «Alberto Garzón»…
#   – Sin datos obtenidos
# [22/172] Procesando «Mario Garcés Sanagustín»…
#   – Sin datos obtenidos
# [23/172] Procesando «Jose Antonio Rodríguez Salas »…
#   – Sin datos obtenidos
# [24/172] Procesando «Juan López de Uralde»…
#   – Sin datos obtenidos
# [25/172] Procesando «Macarena Olona»…
#   – Sin datos obtenidos
# [26/172] Procesando «Patricia Rueda»…
#   – Sin datos obtenidos
# [27/172] Procesando «Carmen Riolobos»…
#   – Sin datos obtenidos
# [28/172] Procesando «VíctorSánchezdelReal»…
#   – Sin datos obtenidos
# [29/172] Procesando «Eloy Suárez Lamata»…
#   – Sin datos obtenidos
# [30/172] Procesando «Odón Elorza Activista por la Democracia»…
#   – Sin datos obtenidos
# [31/172] Procesando «Rodrigo Jiménez Revuelta»…
#   – Sin datos obtenidos
# [32/172] Procesando «Ana Vázquez Blanco»…
#   – Sin datos obtenidos
# [33/172] Procesando «Fuensanta Lima»…
#   – Sin datos obtenidos
# [34/172] Procesando «Carla Toscano»…
#   – Sin datos obtenidos
# [35/172] Procesando «Genís Boadella»…
#   – Sin datos obtenidos
# [36/172] Procesando «Pilar Marcos»…
#   – Sin datos obtenidos
# [37/172] Procesando «Victor Píriz Maya»…
#   – Sin datos obtenidos
# [38/172] Procesando «Joan Capdevila ن»…
#   – Sin datos obtenidos
# [39/172] Procesando «Juan Cuatrecasas Asúa/»…
#   – Sin datos obtenidos
# [40/172] Procesando «Pere Joan Pons Sampietro»…
#   – Sin datos obtenidos
# [41/172] Procesando «Agustín Almodóbar Barceló»…
#   – Sin datos obtenidos
# [42/172] Procesando «Fco. J. Contreras»…
#   – Sin datos obtenidos
# [43/172] Procesando «Pau Marí-Klose»…
#   – Sin datos obtenidos
# [44/172] Procesando «Mariona Illamola Dausà»…
#   – Sin datos obtenidos
# [45/172] Procesando «Yolanda Díaz»…
#   – Sin datos obtenidos
# [46/172] Procesando «sol cruz guzman»…
#   – Sin datos obtenidos
# [47/172] Procesando «Inés Arrimadas»…
#   – Sin datos obtenidos
# [48/172] Procesando «Ione Belarra»…
#   – Sin datos obtenidos
# [49/172] Procesando «Edurne Uriarte»…
#   – Sin datos obtenidos
# [50/172] Procesando «Rocío De Meer ن»…
#   – Sin datos obtenidos
# [51/172] Procesando «Iván Espinosa de los Monteros»…
#   – Sin datos obtenidos
# [52/172] Procesando «Arnau Ramírez»…
#   – Sin datos obtenidos
# [53/172] Procesando «Emilio del Valle»…
#   – Sin datos obtenidos
# [54/172] Procesando «Malena Nevado»…
#   – Sin datos obtenidos
# [55/172] Procesando «Víctor González»…
#   – Sin datos obtenidos
# [56/172] Procesando «Ana Zurita»…
#   – Sin datos obtenidos
# [57/172] Procesando «Georgina Trias»…
#   – Sin datos obtenidos
# [58/172] Procesando «Jose Luis Aceves/»…
#   – Sin datos obtenidos
# [59/172] Procesando «Íñigo Errejón»…
#   – Sin datos obtenidos
# [60/172] Procesando «Xavier Eritja Ciuró»…
#   – Sin datos obtenidos
# [61/172] Procesando «Cristina Esteban Calonje»…
#   – Sin datos obtenidos
# [62/172] Procesando «Mireia Vehí»…
#   – Sin datos obtenidos
# [63/172] Procesando «Mercè Perea Conillas»…
#   – Sin datos obtenidos
# [64/172] Procesando «Santiago Abascal»…
#   – Sin datos obtenidos
# [65/172] Procesando «Ángeles Marra \»…
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 58
#      56 for idx, name in enumerate(names, start=1):
#      57     print(f"[{idx}/{total}] Procesando «{name}»…")
# ---> 58     recs = fetch_data_for(name)
#      59     time.sleep(1)
#      61     if recs:
#
# Cell In[4], line 50, in fetch_data_for(name, max_retries)
#      48         time.sleep(wait)
#      49     else:
# ---> 50         res.raise_for_status()
#      51 print(f"  ✗ [{name}] Falló tras {max_retries} intentos")
#      52 return []
#
# File /opt/tljh/user/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://query.wikidata.org/sparql

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
import datetime
import pandas as pd
import requests
import time

# Parámetros
INPUT_JSON     = 'spain/users_españoles.json'
OUTPUT_XLSX    = 'politicos_españoles.xlsx'
REFERENCE_DATE = datetime.date(2025, 4, 20)
SPARQL_URL     = 'https://query.wikidata.org/sparql'
HEADERS        = {
    'Accept': 'application/json',
    'User-Agent': 'TarjetasVisitaScript/1.0 (tu_email@dominio.com)'
}

# Carga de nombres
with open(INPUT_JSON, encoding='utf-8') as f:
    items = json.load(f)
names = [item['name'] for item in items]

def fetch_data_for(name, max_retries=3):
    q = f"""
    SELECT ?dob ?genderLabel ?partyLabel WHERE {{
      # Etiqueta en español o inglés
      {{ ?person rdfs:label "{name}"@es }} 
      UNION 
      {{ ?person rdfs:label "{name}"@en }}
      # Solo humanos:
      # ?person wdt:P31 wd:Q5.
      # (Opcional) Solo ciudadanos de España:
      # ?person wdt:P27 wd:Q29.
      OPTIONAL {{ ?person wdt:P569 ?dob. }}
      OPTIONAL {{ ?person wdt:P21  ?gender. }}
      OPTIONAL {{ ?person wdt:P102 ?party. }}
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "es,en". }}
    }}
    """
    for intento in range(1, max_retries+1):
        res = requests.post(SPARQL_URL, data={'query': q}, headers=HEADERS)
        if res.status_code == 200:
            return res.json()['results']['bindings']
        elif res.status_code == 429:
            wait = 2 ** (intento - 1)
            print(f"  ↻ [{name}] 429, reintento en {wait}s…")
            time.sleep(wait)
        else:
            res.raise_for_status()
    print(f"  ✗ [{name}] Falló tras {max_retries} intentos")
    return []

rows = []
total = len(names)
for idx, name in enumerate(names, start=1):
    print(f"[{idx}/{total}] Procesando «{name}»…")
    recs = fetch_data_for(name)
    time.sleep(1)

    if recs:
        rec = recs[0]
        # Fecha de nacimiento → edad
        dob_str = rec.get('dob', {}).get('value')
        if dob_str:
            dob = datetime.datetime.fromisoformat(dob_str).date()
            age = (REFERENCE_DATE.year - dob.year
                   - ((REFERENCE_DATE.month, REFERENCE_DATE.day) < (dob.month, dob.day)))
        else:
            age = None

        # Género
        g_raw = rec.get('genderLabel', {}).get('value', '')
        g_text = g_raw.lower()
        if any(k in g_text for k in ['male', 'masculino', 'hombre']):
            gender = 'masculino'
        elif any(k in g_text for k in ['female', 'femenino', 'mujer']):
            gender = 'femenino'
        else:
            gender = ''

        # Partido
        party = rec.get('partyLabel', {}).get('value', '')

        print(f"  ✓ edad: {age or 'N/A'}, género: {gender or 'N/A'}, partido: {party or 'N/A'}")
    else:
        age = None
        gender = ''
        party = ''
        print("  – Sin datos obtenidos")

    rows.append({
        'name':   name,
        'age':    age,
        'gender': gender,
        'party':  party
    })

# Exportar a Excel
df = pd.DataFrame(rows)
df.to_excel(OUTPUT_XLSX, index=False)
print(f"\n✅ Archivo generado: {OUTPUT_XLSX}")
# Out:
# [1/172] Procesando «Gloria Elizo»…
#   ✓ edad: 58, género: femenino, partido: Podemos
# [2/172] Procesando «Andrés Lorite»…
#   – Sin datos obtenidos
# [3/172] Procesando «Inés Sabanés»…
#   ✓ edad: 71, género: femenino, partido: Izquierda Unida
# [4/172] Procesando «José Alcaraz Martos»…
#   – Sin datos obtenidos
# [5/172] Procesando «Marisa Saavedra»…
#   – Sin datos obtenidos
# [6/172] Procesando «Daniel Senderos/»…
#   – Sin datos obtenidos
# [7/172] Procesando «Jaume Asens»…
#   – Sin datos obtenidos
# [8/172] Procesando «Marta Martín Llaguno»…
#   ✓ edad: 52, género: femenino, partido: Ciudadanos
# [9/172] Procesando «Diego Gago Bugarín»…
#   – Sin datos obtenidos
# [10/172] Procesando «Miguel Gutiérrez»…
#   ✓ edad: 23, género: masculino, partido: N/A
# [11/172] Procesando «Rosa Romero»…
#   ✓ edad: 55, género: femenino, partido: Partido Popular
# [12/172] Procesando «Juan Luis Soto Buril»…
#   – Sin datos obtenidos
# [13/172] Procesando «Pilar Cancela/»…
#   – Sin datos obtenidos
# [14/172] Procesando «Néstor Rego»…
#   ✓ edad: 63, género: masculino, partido: Bloque Nacionalista Galego
# [15/172] Procesando «Pedro Sánchez»…
#   ✓ edad: 122, género: masculino, partido: N/A
# [16/172] Procesando «Laura Borràs»…
#   – Sin datos obtenidos
# [17/172] Procesando «Héctor Gómez»…
#   ✓ edad: 46, género: masculino, partido: Partido Socialista Obrero Español
# [18/172] Procesando «mjesus moro almaraz»…
#   – Sin datos obtenidos
# [19/172] Procesando «Ines Granollers»…
#   – Sin datos obtenidos
# [20/172] Procesando «Ricardo Chamorro Delmo»…
#   ✓ edad: 48, género: masculino, partido: Vox
# [21/172] Procesando «Alberto Garzón»…
#   ✓ edad: 39, género: masculino, partido: Partido Comunista de España
# [22/172] Procesando «Mario Garcés Sanagustín»…
#   ✓ edad: 57, género: masculino, partido: Partido Popular
# [23/172] Procesando «Jose Antonio Rodríguez Salas »…
#   – Sin datos obtenidos
# [24/172] Procesando «Juan López de Uralde»…
#   ✓ edad: 61, género: masculino, partido: Verdes Equo
# [25/172] Procesando «Macarena Olona»…
#   – Sin datos obtenidos
# [26/172] Procesando «Patricia Rueda»…
#   – Sin datos obtenidos
# [27/172] Procesando «Carmen Riolobos»…
#   – Sin datos obtenidos
# [28/172] Procesando «VíctorSánchezdelReal»…
#   – Sin datos obtenidos
# [29/172] Procesando «Eloy Suárez Lamata»…
#   – Sin datos obtenidos
# [30/172] Procesando «Odón Elorza Activista por la Democracia»…
#   – Sin datos obtenidos
# [31/172] Procesando «Rodrigo Jiménez Revuelta»…
#   – Sin datos obtenidos
# [32/172] Procesando «Ana Vázquez Blanco»…
#   – Sin datos obtenidos
# [33/172] Procesando «Fuensanta Lima»…
#   – Sin datos obtenidos
# [34/172] Procesando «Carla Toscano»…
#   – Sin datos obtenidos
# [35/172] Procesando «Genís Boadella»…
#   – Sin datos obtenidos
# [36/172] Procesando «Pilar Marcos»…
#   – Sin datos obtenidos
# [37/172] Procesando «Victor Píriz Maya»…
#   – Sin datos obtenidos
# [38/172] Procesando «Joan Capdevila ن»…
#   – Sin datos obtenidos
# [39/172] Procesando «Juan Cuatrecasas Asúa/»…
#   – Sin datos obtenidos
# [40/172] Procesando «Pere Joan Pons Sampietro»…
#   – Sin datos obtenidos
# [41/172] Procesando «Agustín Almodóbar Barceló»…
#   ✓ edad: 47, género: masculino, partido: Partido Popular
# [42/172] Procesando «Fco. J. Contreras»…
#   – Sin datos obtenidos
# [43/172] Procesando «Pau Marí-Klose»…
#   ✓ edad: 52, género: masculino, partido: Partido Socialista Obrero Español
# [44/172] Procesando «Mariona Illamola Dausà»…
#   ✓ edad: 58, género: femenino, partido: N/A
# [45/172] Procesando «Yolanda Díaz»…
#   ✓ edad: 53, género: femenino, partido: Partido Comunista de España
# [46/172] Procesando «sol cruz guzman»…
#   – Sin datos obtenidos
# [47/172] Procesando «Inés Arrimadas»…
#   ✓ edad: 43, género: femenino, partido: Ciudadanos
# [48/172] Procesando «Ione Belarra»…
#   ✓ edad: 37, género: femenino, partido: Podemos
# [49/172] Procesando «Edurne Uriarte»…
#   ✓ edad: 64, género: femenino, partido: Partido Socialista Obrero Español
# [50/172] Procesando «Rocío De Meer ن»…
#   – Sin datos obtenidos
# [51/172] Procesando «Iván Espinosa de los Monteros»…
#   – Sin datos obtenidos
# [52/172] Procesando «Arnau Ramírez»…
#   – Sin datos obtenidos
# [53/172] Procesando «Emilio del Valle»…
#   ✓ edad: 64, género: masculino, partido: Partido Popular
# [54/172] Procesando «Malena Nevado»…
#   – Sin datos obtenidos
# [55/172] Procesando «Víctor González»…
#   – Sin datos obtenidos
# [56/172] Procesando «Ana Zurita»…
#   ✓ edad: 49, género: femenino, partido: N/A
# [57/172] Procesando «Georgina Trias»…
#   – Sin datos obtenidos
# [58/172] Procesando «Jose Luis Aceves/»…
#   – Sin datos obtenidos
# [59/172] Procesando «Íñigo Errejón»…
#   ✓ edad: 41, género: masculino, partido: Podemos
# [60/172] Procesando «Xavier Eritja Ciuró»…
#   – Sin datos obtenidos
# [61/172] Procesando «Cristina Esteban Calonje»…
#   – Sin datos obtenidos
# [62/172] Procesando «Mireia Vehí»…
#   – Sin datos obtenidos
# [63/172] Procesando «Mercè Perea Conillas»…
#   – Sin datos obtenidos
# [64/172] Procesando «Santiago Abascal»…
#   ✓ edad: 49, género: masculino, partido: Partido Popular
# [65/172] Procesando «Ángeles Marra»…
#   ✓ edad: 59, género: femenino, partido: N/A
# [66/172] Procesando «NUET»…
#   – Sin datos obtenidos
# [67/172] Procesando «Cayetana Álvarez de Toledo»…
#   ✓ edad: 50, género: femenino, partido: Partido Popular
# [68/172] Procesando «M Luz Martínez Seijo»…
#   – Sin datos obtenidos
# [69/172] Procesando «Rubén Manso Olivar»…
#   – Sin datos obtenidos
# [70/172] Procesando «Joan Margall Sastre»…
#   ✓ edad: 49, género: masculino, partido: Esquerra Republicana de Catalunya
# [71/172] Procesando «José Ramírez del Río ن»…
#   – Sin datos obtenidos
# [72/172] Procesando «Jon Inarritu»…
#   – Sin datos obtenidos
# [73/172] Procesando «Martina Velarde»…
#   – Sin datos obtenidos
# [74/172] Procesando «Pedro Casares»…
#   ✓ edad: 41, género: masculino, partido: N/A
# [75/172] Procesando «Roberto Morís»…
#   – Sin datos obtenidos
# [76/172] Procesando «Pepe Ortiz Vejer»…
#   – Sin datos obtenidos
# [77/172] Procesando «Jaume Alonso-Cuevillas i Sayrol (JACS)»…
#   – Sin datos obtenidos
# [78/172] Procesando «Montse Mínguez»…
#   – Sin datos obtenidos
# [79/172] Procesando «Meritxell Batet»…
#   ✓ edad: 52, género: femenino, partido: Partido Socialista Obrero Español
# [80/172] Procesando «Cesar Ramos»…
#   – Sin datos obtenidos
# [81/172] Procesando «Ana Oramas»…
#   ✓ edad: 65, género: femenino, partido: Unión de Centro Democrático
# [82/172] Procesando «Antón Gómez-Reino Varela»…
#   – Sin datos obtenidos
# [83/172] Procesando «Ana Pastor Julián»…
#   ✓ edad: 67, género: femenino, partido: Partido Popular
# [84/172] Procesando «Carmen Navarro Lacoba»…
#   – Sin datos obtenidos
# [85/172] Procesando «Ignacio López Cano»…
#   – Sin datos obtenidos
# [86/172] Procesando «Teodoro García Egea»…
#   ✓ edad: 40, género: masculino, partido: Partido Popular
# [87/172] Procesando «María Muñoz»…
#   ✓ edad: 62, género: femenino, partido: N/A
# [88/172] Procesando «Ignacio Garriga»…
#   – Sin datos obtenidos
# [89/172] Procesando «Maria Dantas (@mariadantas.bsky.social)»…
#   – Sin datos obtenidos
# [90/172] Procesando «Valentina Martinez»…
#   – Sin datos obtenidos
# [91/172] Procesando «Pablo Sáez»…
#   – Sin datos obtenidos
# [92/172] Procesando «Concep Cañadell»…
#   – Sin datos obtenidos
# [93/172] Procesando «Bea Fanjul»…
#   – Sin datos obtenidos
# [94/172] Procesando «Miquel Jerez»…
#   – Sin datos obtenidos
# [95/172] Procesando «José Ignacio Echániz»…
#   ✓ edad: 61, género: masculino, partido: Partido Popular
# [96/172] Procesando «Omar Anguita Pérez»…
#   – Sin datos obtenidos
# [97/172] Procesando «Sofía Hernanz Costa»…
#   ✓ edad: 54, género: femenino, partido: Partido Socialista Obrero Español
# [98/172] Procesando «Lídia Guinart Moreno/»…
#   – Sin datos obtenidos
# [99/172] Procesando «Marta Rosique i Saltor»…
#   – Sin datos obtenidos
# [100/172] Procesando «José Zaragoza»…
#   – Sin datos obtenidos
# [101/172] Procesando «Alberto Herrero»…
#   ✓ edad: 57, género: masculino, partido: N/A
# [102/172] Procesando «Carmen Andrés Añón»…
#   ✓ edad: 60, género: femenino, partido: Partido de los Socialistas de Cataluña
# [103/172] Procesando «Belén Fernández/»…
#   – Sin datos obtenidos
# [104/172] Procesando «Oskar Matute»…
#   ✓ edad: 52, género: masculino, partido: Euskal Herria Bildu
# [105/172] Procesando «Sebastian Ledesma Ma»…
#   – Sin datos obtenidos
# [106/172] Procesando «Juanjo Aizcorbe Torra»…
#   – Sin datos obtenidos
# [107/172] Procesando «Pablo Casado Blanco»…
#   ✓ edad: 44, género: masculino, partido: Partido Popular
# [108/172] Procesando «Albert Botran Pahissa»…
#   – Sin datos obtenidos
# [109/172] Procesando «Miriam Nogueras»…
#   – Sin datos obtenidos
# [110/172] Procesando «Susana Sumelzo Jordán»…
#   ✓ edad: 55, género: femenino, partido: Partido Socialista Obrero Español
# [111/172] Procesando «Antònia Jover»…
#   – Sin datos obtenidos
# [112/172] Procesando «Edmundo Bal»…
#   – Sin datos obtenidos
# [113/172] Procesando «Alicia García»…
#   – Sin datos obtenidos
# [114/172] Procesando «Miguel Á. Castellón»…
#   – Sin datos obtenidos
# [115/172] Procesando «Joan Baldoví ;)»…
#   – Sin datos obtenidos
# [116/172] Procesando «Gabriel Rufián»…
#   ✓ edad: 43, género: masculino, partido: Esquerra Republicana de Catalunya
# [117/172] Procesando «Fernando Gutiérrez Díaz de Otazu»…
#   – Sin datos obtenidos
# [118/172] Procesando «Txema Guijarro»…
#   – Sin datos obtenidos
# [119/172] Procesando «German Renau»…
#   – Sin datos obtenidos
# [120/172] Procesando «Marga Prohens»…
#   – Sin datos obtenidos
# [121/172] Procesando «Rafa Lomana»…
#   ✓ edad: 60, género: masculino, partido: Vox
# [122/172] Procesando «Luis Gestoso»…
#   – Sin datos obtenidos
# [123/172] Procesando «Eduardo Carazo»…
#   – Sin datos obtenidos
# [124/172] Procesando «antonio hurtado»…
#   – Sin datos obtenidos
# [125/172] Procesando «Pedro Navarro»…
#   ✓ edad: 425, género: masculino, partido: N/A
# [126/172] Procesando «María Guijarro»…
#   – Sin datos obtenidos
# [127/172] Procesando «Carlos Rojas García»…
#   ✓ edad: 54, género: masculino, partido: Partido Popular
# [128/172] Procesando «Joan Mena»…
#   ✓ edad: 49, género: masculino, partido: Esquerra Unida i Alternativa
# [129/172] Procesando «Rafa Mayoral»…
#   – Sin datos obtenidos
# [130/172] Procesando «Rafael Simancas»…
#   ✓ edad: 58, género: masculino, partido: Partido Socialista Obrero Español
# [131/172] Procesando «Montse Bassa i Coll»…
#   – Sin datos obtenidos
# [132/172] Procesando «José Ángel Alonso»…
#   ✓ edad: 36, género: masculino, partido: N/A
# [133/172] Procesando «Javi Merino»…
#   – Sin datos obtenidos
# [134/172] Procesando «Pablo Iglesias {R}»…
#   – Sin datos obtenidos
# [135/172] Procesando «Sofía Castañón»…
#   ✓ edad: 41, género: femenino, partido: Podemos
# [136/172] Procesando «Teresa Jiménez-Becerril»…
#   ✓ edad: 63, género: femenino, partido: Partido Popular
# [137/172] Procesando «Sara Giménez»…
#   ✓ edad: 33, género: femenino, partido: N/A
# [138/172] Procesando «Reyes Romero»…
#   – Sin datos obtenidos
# [139/172] Procesando «Vicente Tirado»…
#   – Sin datos obtenidos
# [140/172] Procesando «Javier Ortega Smith»…
#   – Sin datos obtenidos
# [141/172] Procesando «Beatriz Micaela Carrillo de los Reyes»…
#   – Sin datos obtenidos
# [142/172] Procesando «Sònia Guerra López/»…
#   – Sin datos obtenidos
# [143/172] Procesando «Laura Berja Vega»…
#   – Sin datos obtenidos
# [144/172] Procesando «Javier Alfonso Cendón»…
#   – Sin datos obtenidos
# [145/172] Procesando «Mar García Puig»…
#   – Sin datos obtenidos
# [146/172] Procesando «Lucía Muñoz Dalda»…
#   ✓ edad: 31, género: femenino, partido: Podemos Islas Baleares
# [147/172] Procesando «Pablo Montesinos»…
#   – Sin datos obtenidos
# [148/172] Procesando «Sergio Gutierrez»…
#   – Sin datos obtenidos
# [149/172] Procesando «Gerardo Pisarello»…
#   ✓ edad: 54, género: masculino, partido: Barcelona en Comú
# [150/172] Procesando «Jordi Salvador Duch»…
#   – Sin datos obtenidos
# [151/172] Procesando «Jaime de Olano»…
#   ✓ edad: 54, género: masculino, partido: Partido Popular
# [152/172] Procesando «Carolina España»…
#   – Sin datos obtenidos
# [153/172] Procesando «Pablo Hispan»…
#   – Sin datos obtenidos
# [154/172] Procesando «Bego Nasarre /»…
#   – Sin datos obtenidos
# [155/172] Procesando «Roser Maestro»…
#   – Sin datos obtenidos
# [156/172] Procesando «María Ramallo»…
#   – Sin datos obtenidos
# [157/172] Procesando «Elvira Ramón»…
#   ✓ edad: 58, género: femenino, partido: Partido Socialista Obrero Español
# [158/172] Procesando «Helena Caballero»…
#   – Sin datos obtenidos
# [159/172] Procesando «Santos Cerdán León»…
#   – Sin datos obtenidos
# [160/172] Procesando «Mertxe Aizpurua»…
#   ✓ edad: 65, género: femenino, partido: Euskal Herria Bildu
# [161/172] Procesando «Isabel Franco ۞»…
#   – Sin datos obtenidos
# [162/172] Procesando «Alfonso R Gómez Celis»…
#   – Sin datos obtenidos
# [163/172] Procesando «Mireia Borrás»…
#   – Sin datos obtenidos
# [164/172] Procesando «Macarena Montesinos de Miguel»…
#   ✓ edad: 63, género: femenino, partido: Partido Popular
# [165/172] Procesando «Sergio Sayas»…
#   ✓ edad: 45, género: masculino, partido: Partido Popular
# [166/172] Procesando «Marisol Sánchez Jódar»…
#   – Sin datos obtenidos
# [167/172] Procesando «Aina Vidal Sáez»…
#   ✓ edad: 40, género: femenino, partido: Iniciativa per Catalunya Verds
# [168/172] Procesando «Javier Sánchez Serna»…
#   ✓ edad: 39, género: masculino, partido: Podemos
# [169/172] Procesando «Pablo Calvo Liste»…
#   – Sin datos obtenidos
# [170/172] Procesando «Cuca Gamarra»…
#   ✓ edad: 50, género: femenino, partido: Partido Popular
# [171/172] Procesando «Isidro M. Oblanca»…
#   – Sin datos obtenidos
# [172/172] Procesando «Eva Patricia Bueno/»…
#   – Sin datos obtenidos
#
# ✅ Archivo generado: politicos_españoles.xlsx

# %%
import pandas as pd
import json
import math

# Rutas de archivos
excel_path = "politicos_españoles.xlsx"  # Ajusta al nombre de tu archivo
json_path  = "politicos_españoles.json"

# 1) Leer el Excel en un DataFrame
df = pd.read_excel(excel_path)

# 2) Convertir a lista de registros (diccionarios)
records = df.to_dict(orient="records")

# 3) Sustituir any NaN --> None para JSON válido
for rec in records:
    for k, v in rec.items():
        if isinstance(v, float) and math.isnan(v):
            rec[k] = None

# 4) Guardar como JSON
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(records, f, ensure_ascii=False, indent=2)

print(f"✅ Convertido '{excel_path}' ({len(records)} filas) a '{json_path}'.")
# Out:
# ✅ Convertido 'politicos_españoles.xlsx' (172 filas) a 'politicos_españoles.json'.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json

# Rutas a tus archivos (ajusta si hace falta)
POLITICOS_IN  = 'politicos_españoles.json'
USERS_IN      = 'spain/users_españoles.json'
POLITICOS_OUT = 'politicos_españoles_actualizado.json'

# 1. Carga de los datos
with open(POLITICOS_IN, encoding='utf-8') as f:
    politicos = json.load(f)

with open(USERS_IN, encoding='utf-8') as f:
    users = json.load(f)

# 2. Construcción del diccionario name → party
party_map = {u['name']: u['party'] for u in users}

# 3. Actualización de cada entrada
for entry in politicos:
    if entry['name'] in party_map:
        entry['party'] = party_map[entry['name']]

# 4. Guardar el JSON actualizado
with open(POLITICOS_OUT, 'w', encoding='utf-8') as f:
    json.dump(politicos, f, ensure_ascii=False, indent=2)

print(f"✅ Partidos actualizados y guardados en «{POLITICOS_OUT}»")

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
import datetime
import requests
import time
import pandas as pd

# — Configuración de rutas —
# Ajusta INPUT_JSON al nombre de tu JSON de entrada con name, gender y party ya completos.
INPUT_JSON     = 'politicos_españoles_actualizado.json'
OUTPUT_JSON    = 'politicos_españoles_con_edad.json'
OUTPUT_XLSX    = 'politicos_españoles_con_edad.xlsx'

# — Parámetros de cálculo —
REFERENCE_DATE = datetime.date(2025, 4, 20)
SPARQL_URL     = 'https://query.wikidata.org/sparql'
HEADERS        = {
    'Accept': 'application/json',
    'User-Agent': 'TarjetasVisitaScript/1.0 (tu_email@dominio.com)'
}
MAX_RETRIES    = 3
PAUSE_SECONDS  = 1  # pausa entre consultas para no saturar el endpoint

def fetch_dob(name: str) -> str | None:
    """
    Consulta Wikidata para obtener la fecha de nacimiento (ISO YYYY‑MM‑DD)
    de la entidad con la etiqueta `name` en es o en.
    Devuelve el string ISO o None si no hay dob.
    """
    query = f"""
    SELECT ?dob WHERE {{
      {{ ?person rdfs:label "{name}"@es }} UNION {{ ?person rdfs:label "{name}"@en }}
      # ?person wdt:P31 wd:Q5.           # solo humanos
      OPTIONAL {{ ?person wdt:P569 ?dob. }}
    }}
    """
    for intento in range(1, MAX_RETRIES + 1):
        resp = requests.post(SPARQL_URL, data={'query': query}, headers=HEADERS)
        if resp.status_code == 200:
            results = resp.json()['results']['bindings']
            if results and 'dob' in results[0]:
                return results[0]['dob']['value']
            return None
        elif resp.status_code == 429:
            # Espera exponencial antes de reintentar
            time.sleep(2 ** (intento - 1))
        else:
            resp.raise_for_status()
    return None

def main():
    # 1. Carga del JSON existente
    with open(INPUT_JSON, encoding='utf-8') as f:
        politicos = json.load(f)

    # 2. Para cada político, buscamos dob y recalculamos age
    for i, entry in enumerate(politicos, start=1):
        name = entry.get('name', '').strip()
        print(f"[{i}/{len(politicos)}] Procesando edad de «{name}»…")
        dob_iso = fetch_dob(name)
        time.sleep(PAUSE_SECONDS)

        if dob_iso:
            dob = datetime.datetime.fromisoformat(dob_iso).date()
            age = (
                REFERENCE_DATE.year - dob.year
                - ((REFERENCE_DATE.month, REFERENCE_DATE.day) < (dob.month, dob.day))
            )
            entry['age'] = age
            print(f"  ✓ edad actualizada: {age}")
        else:
            entry['age'] = None
            print("  – no se encontró fecha de nacimiento")

    # 3. Guardar JSON con edad recalculada
    with open(OUTPUT_JSON, 'w', encoding='utf-8') as f:
        json.dump(politicos, f, ensure_ascii=False, indent=2)
    print(f"\n✅ JSON guardado en «{OUTPUT_JSON}»")

    # 4. Exportar a Excel
    df = pd.DataFrame(politicos)
    df.to_excel(OUTPUT_XLSX, index=False)
    print(f"✅ Excel generado: «{OUTPUT_XLSX}»")

if __name__ == '__main__':
    main()
# Out:
# [1/172] Procesando edad de «Gloria Elizo»…
#   ✓ edad actualizada: 58
# [2/172] Procesando edad de «Andrés Lorite»…
#   – no se encontró fecha de nacimiento
# [3/172] Procesando edad de «Inés Sabanés»…
#   ✓ edad actualizada: 71
# [4/172] Procesando edad de «José Alcaraz Martos»…
#   – no se encontró fecha de nacimiento
# [5/172] Procesando edad de «Marisa Saavedra»…
#   – no se encontró fecha de nacimiento
# [6/172] Procesando edad de «Daniel Senderos/»…
#   – no se encontró fecha de nacimiento
# [7/172] Procesando edad de «Jaume Asens»…
#   – no se encontró fecha de nacimiento
# [8/172] Procesando edad de «Marta Martín Llaguno»…
#   ✓ edad actualizada: 52
# [9/172] Procesando edad de «Diego Gago Bugarín»…
#   – no se encontró fecha de nacimiento
# [10/172] Procesando edad de «Miguel Gutiérrez»…
#   ✓ edad actualizada: 93
# [11/172] Procesando edad de «Rosa Romero»…
#   ✓ edad actualizada: 55
# [12/172] Procesando edad de «Juan Luis Soto Buril»…
#   – no se encontró fecha de nacimiento
# [13/172] Procesando edad de «Pilar Cancela/»…
#   – no se encontró fecha de nacimiento
# [14/172] Procesando edad de «Néstor Rego»…
#   ✓ edad actualizada: 63
# [15/172] Procesando edad de «Pedro Sánchez»…
#   – no se encontró fecha de nacimiento
# [16/172] Procesando edad de «Laura Borràs»…
#   – no se encontró fecha de nacimiento
# [17/172] Procesando edad de «Héctor Gómez»…
#   ✓ edad actualizada: 37
# [18/172] Procesando edad de «Jesus moro almaraz»…
#   – no se encontró fecha de nacimiento
# [19/172] Procesando edad de «Ines Granollers»…
#   – no se encontró fecha de nacimiento
# [20/172] Procesando edad de «Ricardo Chamorro Delmo»…
#   ✓ edad actualizada: 48
# [21/172] Procesando edad de «Alberto Garzón»…
#   ✓ edad actualizada: 39
# [22/172] Procesando edad de «Mario Garcés Sanagustín»…
#   ✓ edad actualizada: 57
# [23/172] Procesando edad de «Jose Antonio Rodríguez Salas »…
#   – no se encontró fecha de nacimiento
# [24/172] Procesando edad de «Juan López de Uralde»…
#   ✓ edad actualizada: 61
# [25/172] Procesando edad de «Macarena Olona»…
#   – no se encontró fecha de nacimiento
# [26/172] Procesando edad de «Patricia Rueda»…
#   – no se encontró fecha de nacimiento
# [27/172] Procesando edad de «Carmen Riolobos»…
#   – no se encontró fecha de nacimiento
# [28/172] Procesando edad de «VíctorSánchezdelReal»…
#   – no se encontró fecha de nacimiento
# [29/172] Procesando edad de «Eloy Suárez Lamata»…
#   – no se encontró fecha de nacimiento
# [30/172] Procesando edad de «Odón Elorza»…
#   ✓ edad actualizada: 69
# [31/172] Procesando edad de «Rodrigo Jiménez Revuelta»…
#   ✓ edad actualizada: 52
# [32/172] Procesando edad de «Ana Vázquez Blanco»…
#   – no se encontró fecha de nacimiento
# [33/172] Procesando edad de «Fuensanta Lima»…
#   – no se encontró fecha de nacimiento
# [34/172] Procesando edad de «Carla Toscano»…
#   – no se encontró fecha de nacimiento
# [35/172] Procesando edad de «Genís Boadella»…
#   – no se encontró fecha de nacimiento
# [36/172] Procesando edad de «Pilar Marcos»…
#   – no se encontró fecha de nacimiento
# [37/172] Procesando edad de «Victor Píriz Maya»…
#   – no se encontró fecha de nacimiento
# [38/172] Procesando edad de «Joan Capdevila»…
#   ✓ edad actualizada: 47
# [39/172] Procesando edad de «Juan Cuatrecasas Asúa»…
#   – no se encontró fecha de nacimiento
# [40/172] Procesando edad de «Pere Joan Pons Sampietro»…
#   – no se encontró fecha de nacimiento
# [41/172] Procesando edad de «Agustín Almodóbar Barceló»…
#   ✓ edad actualizada: 47
# [42/172] Procesando edad de «Federico. J. Contreras»…
#   – no se encontró fecha de nacimiento
# [43/172] Procesando edad de «Pau Marí-Klose»…
#   ✓ edad actualizada: 52
# [44/172] Procesando edad de «Mariona Illamola Dausà»…
#   ✓ edad actualizada: 58
# [45/172] Procesando edad de «Yolanda Díaz»…
#   ✓ edad actualizada: 53
# [46/172] Procesando edad de «sol cruz guzman»…
#   – no se encontró fecha de nacimiento
# [47/172] Procesando edad de «Inés Arrimadas»…
#   ✓ edad actualizada: 43
# [48/172] Procesando edad de «Ione Belarra»…
#   ✓ edad actualizada: 37
# [49/172] Procesando edad de «Edurne Uriarte»…
#   ✓ edad actualizada: 64
# [50/172] Procesando edad de «Rocío De Meer ن»…
#   – no se encontró fecha de nacimiento
# [51/172] Procesando edad de «Iván Espinosa de los Monteros»…
#   – no se encontró fecha de nacimiento
# [52/172] Procesando edad de «Arnau Ramírez»…
#   – no se encontró fecha de nacimiento
# [53/172] Procesando edad de «Emilio del Valle»…
#   ✓ edad actualizada: 64
# [54/172] Procesando edad de «Malena Nevado»…
#   – no se encontró fecha de nacimiento
# [55/172] Procesando edad de «Víctor González»…
#   ✓ edad actualizada: 68
# [56/172] Procesando edad de «Ana Zurita»…
#   ✓ edad actualizada: 49
# [57/172] Procesando edad de «Georgina Trias»…
#   – no se encontró fecha de nacimiento
# [58/172] Procesando edad de «Jose Luis Aceves/»…
#   – no se encontró fecha de nacimiento
# [59/172] Procesando edad de «Íñigo Errejón»…
#   ✓ edad actualizada: 41
# [60/172] Procesando edad de «Xavier Eritja Ciuró»…
#   – no se encontró fecha de nacimiento
# [61/172] Procesando edad de «Cristina Esteban Calonje»…
#   – no se encontró fecha de nacimiento
# [62/172] Procesando edad de «Mireia Vehí»…
#   – no se encontró fecha de nacimiento
# [63/172] Procesando edad de «Mercè Perea Conillas»…
#   – no se encontró fecha de nacimiento
# [64/172] Procesando edad de «Santiago Abascal»…
#   ✓ edad actualizada: 49
# [65/172] Procesando edad de «Ángeles Marra»…
#   ✓ edad actualizada: 59
# [66/172] Procesando edad de «NUET»…
#   – no se encontró fecha de nacimiento
# [67/172] Procesando edad de «Cayetana Álvarez de Toledo»…
#   ✓ edad actualizada: 50
# [68/172] Procesando edad de «María Luz Martínez Seijo»…
#   – no se encontró fecha de nacimiento
# [69/172] Procesando edad de «Rubén Manso Olivar»…
#   – no se encontró fecha de nacimiento
# [70/172] Procesando edad de «Joan Margall Sastre»…
#   ✓ edad actualizada: 49
# [71/172] Procesando edad de «José Ramírez del Río ن»…
#   – no se encontró fecha de nacimiento
# [72/172] Procesando edad de «Jon Inarritu»…
#   – no se encontró fecha de nacimiento
# [73/172] Procesando edad de «Martina Velarde»…
#   – no se encontró fecha de nacimiento
# [74/172] Procesando edad de «Pedro Casares»…
#   ✓ edad actualizada: 41
# [75/172] Procesando edad de «Roberto Morís»…
#   – no se encontró fecha de nacimiento
# [76/172] Procesando edad de «Pepe Ortiz Vejer»…
#   – no se encontró fecha de nacimiento
# [77/172] Procesando edad de «Jaume Alonso-Cuevillas i Sayrol (JACS)»…
#   – no se encontró fecha de nacimiento
# [78/172] Procesando edad de «Montse Mínguez»…
#   – no se encontró fecha de nacimiento
# [79/172] Procesando edad de «Meritxell Batet»…
#   ✓ edad actualizada: 52
# [80/172] Procesando edad de «Cesar Ramos»…
#   ✓ edad actualizada: 40
# [81/172] Procesando edad de «Ana Oramas»…
#   ✓ edad actualizada: 65
# [82/172] Procesando edad de «Antón Gómez-Reino Varela»…
#   – no se encontró fecha de nacimiento
# [83/172] Procesando edad de «Ana Pastor Julián»…
#   ✓ edad actualizada: 67
# [84/172] Procesando edad de «Carmen Navarro Lacoba»…
#   – no se encontró fecha de nacimiento
# [85/172] Procesando edad de «Ignacio López Cano»…
#   ✓ edad actualizada: 48
# [86/172] Procesando edad de «Teodoro García Egea»…
#   ✓ edad actualizada: 40
# [87/172] Procesando edad de «María Muñoz»…
#   ✓ edad actualizada: 57
# [88/172] Procesando edad de «Ignacio Garriga»…
#   – no se encontró fecha de nacimiento
# [89/172] Procesando edad de «Maria Dantas»…
#   – no se encontró fecha de nacimiento
# [90/172] Procesando edad de «Valentina Martinez»…
#   ✓ edad actualizada: 25
# [91/172] Procesando edad de «Pablo Sáez»…
#   – no se encontró fecha de nacimiento
# [92/172] Procesando edad de «Concepción Cañadell»…
#   – no se encontró fecha de nacimiento
# [93/172] Procesando edad de «Bea Fanjul»…
#   – no se encontró fecha de nacimiento
# [94/172] Procesando edad de «Miquel Jerez»…
#   – no se encontró fecha de nacimiento
# [95/172] Procesando edad de «José Ignacio Echániz»…
#   ✓ edad actualizada: 61
# [96/172] Procesando edad de «Omar Anguita Pérez»…
#   – no se encontró fecha de nacimiento
# [97/172] Procesando edad de «Sofía Hernanz Costa»…
#   ✓ edad actualizada: 54
# [98/172] Procesando edad de «Lídia Guinart Moreno/»…
#   – no se encontró fecha de nacimiento
# [99/172] Procesando edad de «Marta Rosique i Saltor»…
#   – no se encontró fecha de nacimiento
# [100/172] Procesando edad de «José Zaragoza»…
#   ✓ edad actualizada: 398
# [101/172] Procesando edad de «Alberto Herrero»…
#   ✓ edad actualizada: 57
# [102/172] Procesando edad de «Carmen Andrés Añón»…
#   ✓ edad actualizada: 60
# [103/172] Procesando edad de «Belén Fernández/»…
#   – no se encontró fecha de nacimiento
# [104/172] Procesando edad de «Oskar Matute»…
#   ✓ edad actualizada: 52
# [105/172] Procesando edad de «Sebastian Ledesma Ma»…
#   – no se encontró fecha de nacimiento
# [106/172] Procesando edad de «Juanjo Aizcorbe Torra»…
#   – no se encontró fecha de nacimiento
# [107/172] Procesando edad de «Pablo Casado Blanco»…
#   ✓ edad actualizada: 44
# [108/172] Procesando edad de «Albert Botran Pahissa»…
#   – no se encontró fecha de nacimiento
# [109/172] Procesando edad de «Miriam Nogueras»…
#   – no se encontró fecha de nacimiento
# [110/172] Procesando edad de «Susana Sumelzo Jordán»…
#   ✓ edad actualizada: 55
# [111/172] Procesando edad de «Antònia Jover»…
#   – no se encontró fecha de nacimiento
# [112/172] Procesando edad de «Edmundo Bal»…
#   – no se encontró fecha de nacimiento
# [113/172] Procesando edad de «Alicia García»…
#   – no se encontró fecha de nacimiento
# [114/172] Procesando edad de «Miguel Á. Castellón»…
#   – no se encontró fecha de nacimiento
# [115/172] Procesando edad de «Joan Baldoví ;)»…
#   – no se encontró fecha de nacimiento
# [116/172] Procesando edad de «Gabriel Rufián»…
#   ✓ edad actualizada: 43
# [117/172] Procesando edad de «Fernando Gutiérrez Díaz de Otazu»…
#   – no se encontró fecha de nacimiento
# [118/172] Procesando edad de «Txema Guijarro»…
#   – no se encontró fecha de nacimiento
# [119/172] Procesando edad de «German Renau»…
#   – no se encontró fecha de nacimiento
# [120/172] Procesando edad de «Marga Prohens»…
#   – no se encontró fecha de nacimiento
# [121/172] Procesando edad de «Rafa Lomana»…
#   ✓ edad actualizada: 60
# [122/172] Procesando edad de «Luis Gestoso»…
#   – no se encontró fecha de nacimiento
# [123/172] Procesando edad de «Eduardo Carazo»…
#   – no se encontró fecha de nacimiento
# [124/172] Procesando edad de «antonio hurtado»…
#   – no se encontró fecha de nacimiento
# [125/172] Procesando edad de «Pedro Navarro»…
#   ✓ edad actualizada: 425
# [126/172] Procesando edad de «María Guijarro»…
#   – no se encontró fecha de nacimiento
# [127/172] Procesando edad de «Carlos Rojas García»…
#   ✓ edad actualizada: 54
# [128/172] Procesando edad de «Joan Mena»…
#   ✓ edad actualizada: 49
# [129/172] Procesando edad de «Rafa Mayoral»…
#   – no se encontró fecha de nacimiento
# [130/172] Procesando edad de «Rafael Simancas»…
#   ✓ edad actualizada: 58
# [131/172] Procesando edad de «Montse Bassa i Coll»…
#   – no se encontró fecha de nacimiento
# [132/172] Procesando edad de «José Ángel Alonso»…
#   ✓ edad actualizada: 36
# [133/172] Procesando edad de «Javi Merino»…
#   – no se encontró fecha de nacimiento
# [134/172] Procesando edad de «Pablo Iglesias»…
#   – no se encontró fecha de nacimiento
# [135/172] Procesando edad de «Sofía Castañón»…
#   ✓ edad actualizada: 41
# [136/172] Procesando edad de «Teresa Jiménez-Becerril»…
#   ✓ edad actualizada: 63
# [137/172] Procesando edad de «Sara Giménez»…
#   ✓ edad actualizada: 33
# [138/172] Procesando edad de «Reyes Romero»…
#   – no se encontró fecha de nacimiento
# [139/172] Procesando edad de «Vicente Tirado»…
#   – no se encontró fecha de nacimiento
# [140/172] Procesando edad de «Javier Ortega Smith»…
#   – no se encontró fecha de nacimiento
# [141/172] Procesando edad de «Beatriz Micaela Carrillo de los Reyes»…
#   – no se encontró fecha de nacimiento
# [142/172] Procesando edad de «Sònia Guerra López/»…
#   – no se encontró fecha de nacimiento
# [143/172] Procesando edad de «Laura Berja Vega»…
#   – no se encontró fecha de nacimiento
# [144/172] Procesando edad de «Javier Alfonso Cendón»…
#   – no se encontró fecha de nacimiento
# [145/172] Procesando edad de «Mar García Puig»…
#   – no se encontró fecha de nacimiento
# [146/172] Procesando edad de «Lucía Muñoz Dalda»…
#   ✓ edad actualizada: 31
# [147/172] Procesando edad de «Pablo Montesinos»…
#   – no se encontró fecha de nacimiento
# [148/172] Procesando edad de «Sergio Gutierrez»…
#   – no se encontró fecha de nacimiento
# [149/172] Procesando edad de «Gerardo Pisarello»…
#   ✓ edad actualizada: 126
# [150/172] Procesando edad de «Jordi Salvador Duch»…
#   – no se encontró fecha de nacimiento
# [151/172] Procesando edad de «Jaime de Olano»…
#   ✓ edad actualizada: 54
# [152/172] Procesando edad de «Carolina España»…
#   – no se encontró fecha de nacimiento
# [153/172] Procesando edad de «Pablo Hispan»…
#   – no se encontró fecha de nacimiento
# [154/172] Procesando edad de «Bego Nasarre»…
#   – no se encontró fecha de nacimiento
# [155/172] Procesando edad de «Roser Maestro»…
#   – no se encontró fecha de nacimiento
# [156/172] Procesando edad de «María Ramallo»…
#   – no se encontró fecha de nacimiento
# [157/172] Procesando edad de «Elvira Ramón»…
#   ✓ edad actualizada: 58
# [158/172] Procesando edad de «Helena Caballero»…
#   – no se encontró fecha de nacimiento
# [159/172] Procesando edad de «Santos Cerdán León»…
#   ✓ edad actualizada: 55
# [160/172] Procesando edad de «Mertxe Aizpurua»…
#   ✓ edad actualizada: 65
# [161/172] Procesando edad de «Isabel Franco»…
#   ✓ edad actualizada: 39
# [162/172] Procesando edad de «Alfonso R Gómez Celis»…
#   – no se encontró fecha de nacimiento
# [163/172] Procesando edad de «Mireia Borrás»…
#   – no se encontró fecha de nacimiento
# [164/172] Procesando edad de «Macarena Montesinos de Miguel»…
#   ✓ edad actualizada: 63
# [165/172] Procesando edad de «Sergio Sayas»…
#   ✓ edad actualizada: 45
# [166/172] Procesando edad de «Marisol Sánchez Jódar»…
#   ✓ edad actualizada: 45
# [167/172] Procesando edad de «Aina Vidal Sáez»…
#   ✓ edad actualizada: 40
# [168/172] Procesando edad de «Javier Sánchez Serna»…
#   ✓ edad actualizada: 39
# [169/172] Procesando edad de «Pablo Calvo Liste»…
#   – no se encontró fecha de nacimiento
# [170/172] Procesando edad de «Cuca Gamarra»…
#   ✓ edad actualizada: 50
# [171/172] Procesando edad de «Isidro M. Oblanca»…
#   – no se encontró fecha de nacimiento
# [172/172] Procesando edad de «Eva Patricia Bueno/»…
#   – no se encontró fecha de nacimiento
#
# ✅ JSON guardado en «politicos_españoles_con_edad.json»
# ✅ Excel generado: «politicos_españoles_con_edad.xlsx»

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
import datetime
import pandas as pd
import requests
import time

# Parámetros
INPUT_JSON     = 'grecia_anotados/users_griegos.json'
OUTPUT_XLSX    = 'politicos_griegos.xlsx'
REFERENCE_DATE = datetime.date(2025, 4, 20)
SPARQL_URL     = 'https://query.wikidata.org/sparql'
HEADERS        = {
    'Accept': 'application/json',
    'User-Agent': 'TarjetasVisitaScript/1.0 (tu_email@dominio.com)'
}

# Carga de nombres
with open(INPUT_JSON, encoding='utf-8') as f:
    items = json.load(f)
names = [item['name'] for item in items]

def fetch_data_for(name, max_retries=3):
    q = f"""
    SELECT ?dob ?genderLabel ?partyLabel WHERE {{
      # Etiqueta en griego o inglés
      {{ ?person rdfs:label "{name}"@el }} 
      UNION 
      {{ ?person rdfs:label "{name}"@en }}
      # Solo humanos:
      # ?person wdt:P31 wd:Q5.
      OPTIONAL {{ ?person wdt:P569 ?dob. }}
      OPTIONAL {{ ?person wdt:P21  ?gender. }}
      OPTIONAL {{ ?person wdt:P102 ?party. }}
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "el,en". }}
    }}
    """
    for intento in range(1, max_retries+1):
        res = requests.post(SPARQL_URL, data={'query': q}, headers=HEADERS)
        if res.status_code == 200:
            return res.json()['results']['bindings']
        elif res.status_code == 429:
            wait = 2 ** (intento - 1)
            print(f"  ↻ [{name}] 429, reintento en {wait}s…")
            time.sleep(wait)
        else:
            res.raise_for_status()
    print(f"  ✗ [{name}] Falló tras {max_retries} intentos")
    return []

rows = []
total = len(names)
for idx, name in enumerate(names, start=1):
    print(f"[{idx}/{total}] Procesando «{name}»…")
    recs = fetch_data_for(name)
    time.sleep(1)

    if recs:
        rec = recs[0]
        # Fecha de nacimiento → edad
        dob_str = rec.get('dob', {}).get('value')
        if dob_str:
            dob = datetime.datetime.fromisoformat(dob_str).date()
            age = (REFERENCE_DATE.year - dob.year
                   - ((REFERENCE_DATE.month, REFERENCE_DATE.day) < (dob.month, dob.day)))
        else:
            age = None

        # Género
        g_raw = rec.get('genderLabel', {}).get('value', '')
        g_text = g_raw.lower()
        if any(k in g_text for k in ['male', 'masculino', 'άνδρας', 'man']):
            gender = 'masculino'
        elif any(k in g_text for k in ['female', 'femenino', 'γυναίκα', 'woman']):
            gender = 'femenino'
        else:
            gender = ''

        # Partido
        party = rec.get('partyLabel', {}).get('value', '')

        print(f"  ✓ edad: {age or 'N/A'}, género: {gender or 'N/A'}, partido: {party or 'N/A'}")
    else:
        age = None
        gender = ''
        party = ''
        print("  – Sin datos obtenidos")

    rows.append({
        'name':   name,
        'age':    age,
        'gender': gender,
        'party':  party
    })

# Exportar a Excel
df = pd.DataFrame(rows)
df.to_excel(OUTPUT_XLSX, index=False)
print(f"\n✅ Archivo generado: {OUTPUT_XLSX}")
# Out:
# [1/142] Procesando «Giannis Plakiotakis»…
#   ✓ edad: N/A, género: masculino, partido: N/A
# [2/142] Procesando «Κατερίνα Νοτοπούλου»…
#   ✓ edad: 36, género: femenino, partido: N/A
# [3/142] Procesando «Costas Zachariadis»…
#   – Sin datos obtenidos
# [4/142] Procesando «Χάρης Μαμουλάκης»…
#   – Sin datos obtenidos
# [5/142] Procesando «Δημήτρης Τζανακόπουλος»…
#   ✓ edad: 42, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [6/142] Procesando «Βασίλης Βιλιάρδος»…
#   ✓ edad: 70, género: masculino, partido: N/A
# [7/142] Procesando «Μανούσος Βολουδάκης»…
#   ✓ edad: 141, género: masculino, partido: N/A
# [8/142] Procesando «Χρήστος Γιαννούλης»…
#   ✓ edad: 56, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [9/142] Procesando «andreasxanthos»…
#   – Sin datos obtenidos
# [10/142] Procesando «Stratos Simopoulos»…
#   ✓ edad: 65, género: masculino, partido: N/A
# [11/142] Procesando «Θεόφιλος Λεονταρίδης»…
#   ✓ edad: 69, género: masculino, partido: Νέα Δημοκρατία
# [12/142] Procesando «Νίκος Ε. Ηγουμενίδης»…
#   – Sin datos obtenidos
# [13/142] Procesando «Βασίλης Κεγκέρογλου»…
#   ✓ edad: 64, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [14/142] Procesando «Άγγελος Τσιγκρής»…
#   – Sin datos obtenidos
# [15/142] Procesando «Έφη Αχτσιόγλου»…
#   ✓ edad: 40, género: femenino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [16/142] Procesando «Κώστας Καραμανλής»…
#   ✓ edad: 68, género: masculino, partido: Νέα Δημοκρατία
# [17/142] Procesando «Ιωάννης Σαρακιώτης • Ioannis Sarakiotis»…
#   – Sin datos obtenidos
# [18/142] Procesando «Κέλλας Χρήστος»…
#   – Sin datos obtenidos
# [19/142] Procesando «Κυριάκος Βελόπουλος»…
#   ✓ edad: 59, género: masculino, partido: Νέα Δημοκρατία
# [20/142] Procesando «Chitas Constantinos»…
#   – Sin datos obtenidos
# [21/142] Procesando «Γιαννης Λοβερδος»…
#   – Sin datos obtenidos
# [22/142] Procesando «Fotini Bakadima»…
#   – Sin datos obtenidos
# [23/142] Procesando «Όλγα Γεροβασίλη»…
#   ✓ edad: 64, género: femenino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [24/142] Procesando «Theodoros Karaoglou»…
#   ✓ edad: 64, género: masculino, partido: Νέα Δημοκρατία
# [25/142] Procesando «Νεκτάριος Σαντορινιός»…
#   ✓ edad: 52, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [26/142] Procesando «Ευρ. Στυλιανίδης»…
#   – Sin datos obtenidos
# [27/142] Procesando «Θάνος Μωραΐτης»…
#   ✓ edad: 55, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [28/142] Procesando «Dimitris Kairidis - Δημήτρης Καιρίδης»…
#   – Sin datos obtenidos
# [29/142] Procesando «Hüseyin Zeybek»…
#   – Sin datos obtenidos
# [30/142] Procesando «Nikos Dendias»…
#   ✓ edad: 65, género: masculino, partido: Νέα Δημοκρατία
# [31/142] Procesando «Χριστίνα Αλεξοπούλου/ Christina Alexopoulou»…
#   – Sin datos obtenidos
# [32/142] Procesando «Fofi Gennimata»…
#   ✓ edad: 60, género: femenino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [33/142] Procesando «Δημήτρης Κωνσταντόπουλος»…
#   ✓ edad: 46, género: masculino, partido: N/A
# [34/142] Procesando «Κώστας Τζαβάρας»…
#   ✓ edad: 69, género: masculino, partido: Νέα Δημοκρατία
# [35/142] Procesando «Μπάμπης Παπαδημητρίου»…
#   ✓ edad: 71, género: masculino, partido: Νέα Δημοκρατία
# [36/142] Procesando «ANASTASIA-EKATERINI ALEXOPOULOU»…
#   – Sin datos obtenidos
# [37/142] Procesando «Σάββας Αναστασιάδης»…
#   ✓ edad: 70, género: masculino, partido: Νέα Δημοκρατία
# [38/142] Procesando «Kostas Tsiaras»…
#   ✓ edad: 58, género: masculino, partido: Νέα Δημοκρατία
# [39/142] Procesando «Harry Theoharis»…
#   – Sin datos obtenidos
# [40/142] Procesando «Nikos Sirmalenios»…
#   – Sin datos obtenidos
# [41/142] Procesando «Yiannis Vroutsis»…
#   – Sin datos obtenidos
# [42/142] Procesando «Giorgos Koumoutsakos»…
#   ✓ edad: 63, género: masculino, partido: Νέα Δημοκρατία
# [43/142] Procesando «Μάξιμος Χαρακόπουλος»…
#   – Sin datos obtenidos
# [44/142] Procesando «Yanis Varoufakis»…
#   ✓ edad: 64, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [45/142] Procesando «Αλέξης Τσίπρας - Alexis Tsipras»…
#   – Sin datos obtenidos
# [46/142] Procesando «Άδωνις Γεωργιάδης»…
#   ✓ edad: 52, género: masculino, partido: Νέα Δημοκρατία
# [47/142] Procesando «Μιχάλης Κατρίνης»…
#   ✓ edad: 49, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [48/142] Procesando «Kostas Skrekas | Κώστας Σκρέκας»…
#   – Sin datos obtenidos
# [49/142] Procesando «Marios Katsis»…
#   ✓ edad: 40, género: masculino, partido: N/A
# [50/142] Procesando «Lefteris Avgenakis»…
#   – Sin datos obtenidos
# [51/142] Procesando «Andreas Loverdos»…
#   ✓ edad: 68, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [52/142] Procesando «Giannis Amanatidis»…
#   – Sin datos obtenidos
# [53/142] Procesando «Γιώργος Φραγγίδης»…
#   – Sin datos obtenidos
# [54/142] Procesando «Niki Kerameus»…
#   – Sin datos obtenidos
# [55/142] Procesando «Natasa Gkara»…
#   – Sin datos obtenidos
# [56/142] Procesando «Τάκης Θεοδωρικάκος»…
#   ✓ edad: 60, género: masculino, partido: Νέα Δημοκρατία
# [57/142] Procesando «Varvitsiotis Miltiadis»…
#   – Sin datos obtenidos
# [58/142] Procesando «George Logiadis»…
#   – Sin datos obtenidos
# [59/142] Procesando «Θάνος Πλεύρης»…
#   ✓ edad: 47, género: masculino, partido: Νέα Δημοκρατία
# [60/142] Procesando «BiziouStella»…
#   – Sin datos obtenidos
# [61/142] Procesando «Tasos Chatzivasileiou»…
#   – Sin datos obtenidos
# [62/142] Procesando «Stavros Kalafatis»…
#   ✓ edad: 59, género: masculino, partido: Νέα Δημοκρατία
# [63/142] Procesando «𝙍𝙖𝙡𝙡𝙞𝙖 𝘾𝙝𝙧𝙞𝙨𝙩𝙞𝙙𝙤𝙪»…
#   – Sin datos obtenidos
# [64/142] Procesando «Γιάννης Καλλιάνος»…
#   ✓ edad: 46, género: masculino, partido: Νέα Δημοκρατία
# [65/142] Procesando «Μακάριος Λαζαρίδης»…
#   – Sin datos obtenidos
# [66/142] Procesando «Κώστας Μπάρκας - Kostas Barkas»…
#   – Sin datos obtenidos
# [67/142] Procesando «Kriton Arsenis»…
#   ✓ edad: 47, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [68/142] Procesando «Ανδρέας Νικολακόπουλος»…
#   ✓ edad: 50, género: masculino, partido: N/A
# [69/142] Procesando «Γιώργος Αμυράς»…
#   ✓ edad: 57, género: masculino, partido: Το Ποτάμι
# [70/142] Procesando «Άννα Ευθυμίου»…
#   ✓ edad: N/A, género: femenino, partido: N/A
# [71/142] Procesando «Ανδρέας Πουλάς»…
#   ✓ edad: N/A, género: masculino, partido: N/A
# [72/142] Procesando «Christos Staikouras»…
#   – Sin datos obtenidos
# [73/142] Procesando «Apatzidi_Maria»…
#   – Sin datos obtenidos
# [74/142] Procesando «Ασημίνα Σκόνδρα»…
#   – Sin datos obtenidos
# [75/142] Procesando «A.Δημοσχάκης»…
#   – Sin datos obtenidos
# [76/142] Procesando «Γιώργος Στύλιος»…
#   ✓ edad: 54, género: masculino, partido: Νέα Δημοκρατία
# [77/142] Procesando «Vassilis Kikilias»…
#   – Sin datos obtenidos
# [78/142] Procesando «Αγγελική Αδαμοπούλου- Aggeliki Adamopoulou»…
#   – Sin datos obtenidos
# [79/142] Procesando «Iasonas Fotilas»…
#   – Sin datos obtenidos
# [80/142] Procesando «Georgios Kaminis»…
#   ✓ edad: 70, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [81/142] Procesando «Manos Konsolas»…
#   – Sin datos obtenidos
# [82/142] Procesando «Σοφία Σακοράφα»…
#   ✓ edad: 67, género: femenino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [83/142] Procesando «Χρ.Βερναρδάκης»…
#   – Sin datos obtenidos
# [84/142] Procesando «Simos Kedikoglou»…
#   ✓ edad: 51, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [85/142] Procesando «Balafas Yiannis»…
#   – Sin datos obtenidos
# [86/142] Procesando «Ντόρα Μπακογιάννη»…
#   ✓ edad: 70, género: femenino, partido: Νέα Δημοκρατία
# [87/142] Procesando «Γιάννης Δραγασάκης»…
#   ✓ edad: 78, género: masculino, partido: Κομμουνιστικό Κόμμα Ελλάδας
# [88/142] Procesando «constantinosbogdanos»…
#   – Sin datos obtenidos
# [89/142] Procesando «Ζωή Ράπτη»…
#   ✓ edad: 58, género: femenino, partido: Νέα Δημοκρατία
# [90/142] Procesando «Marietta Giannakou»…
#   ✓ edad: 73, género: femenino, partido: Νέα Δημοκρατία
# [91/142] Procesando «Nikos Panagiotopoulos»…
#   ✓ edad: 80, género: masculino, partido: N/A
# [92/142] Procesando «Avgerinopoulou Dion»…
#   – Sin datos obtenidos
# [93/142] Procesando «Αλέξανδρος Τριανταφυλλίδης»…
#   ✓ edad: 185, género: masculino, partido: Ένωσις Κέντρου
# [94/142] Procesando «Νίκος Παππάς»…
#   ✓ edad: 119, género: masculino, partido: N/A
# [95/142] Procesando «Τάνια Ελευθεριάδου»…
#   – Sin datos obtenidos
# [96/142] Procesando «Μπουτσικάκης Χριστόφορος /Boutsikakis Christoforos»…
#   – Sin datos obtenidos
# [97/142] Procesando «Giorgos Varemenos»…
#   ✓ edad: 72, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [98/142] Procesando «ΘΑΝΑΣΗΣ ΔΑΒΑΚΗΣ/THANASIS DAVAKIS»…
#   – Sin datos obtenidos
# [99/142] Procesando «Βαγγέλης Αποστόλου»…
#   ✓ edad: 75, género: masculino, partido: Συνασπισμός της Αριστεράς, των Κινημάτων και της Οικολογίας
# [100/142] Procesando «Θεόφιλος Ξανθόπουλος»…
#   ✓ edad: 68, género: masculino, partido: N/A
# [101/142] Procesando «ΚΩΣΤΑΣ ΜΠΟΥΜΠΑΣ»…
#   – Sin datos obtenidos
# [102/142] Procesando «Socratis Famellos»…
#   – Sin datos obtenidos
# [103/142] Procesando «Giorgos Kotsos - Κωτσός Γιώργος»…
#   – Sin datos obtenidos
# [104/142] Procesando «Kyriakos Mitsotakis»…
#   ✓ edad: 57, género: masculino, partido: Νέα Δημοκρατία
# [105/142] Procesando «Panos Skourletis»…
#   ✓ edad: 63, género: masculino, partido: Νέα Αριστερά
# [106/142] Procesando «Kastanidis Haris»…
#   – Sin datos obtenidos
# [107/142] Procesando «kyranakis»…
#   – Sin datos obtenidos
# [108/142] Procesando «Nadia Giannakopoulou»…
#   ✓ edad: 47, género: femenino, partido: N/A
# [109/142] Procesando «Νότης Μηταράκης - Notis Mitarachi»…
#   – Sin datos obtenidos
# [110/142] Procesando «Christos Dimas»…
#   ✓ edad: 44, género: masculino, partido: Νέα Δημοκρατία
# [111/142] Procesando «Αλέξης Χαρίτσης»…
#   ✓ edad: 47, género: masculino, partido: Συνασπισμός της Αριστεράς, των Κινημάτων και της Οικολογίας
# [112/142] Procesando «Νικήτας Κακλαμάνης»…
#   ✓ edad: 79, género: masculino, partido: Νέα Δημοκρατία
# [113/142] Procesando «Γιώργος Τσίπρας»…
#   ✓ edad: 59, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [114/142] Procesando «Βασίλης Σπανάκης»…
#   ✓ edad: 49, género: masculino, partido: N/A
# [115/142] Procesando «Αλέξανδρος Αυλωνίτης»…
#   ✓ edad: 68, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [116/142] Procesando «Νίκος Μανωλάκος»…
#   – Sin datos obtenidos
# [117/142] Procesando «Γιώργος Κώτσηρας»…
#   ✓ edad: 41, género: masculino, partido: Νέα Δημοκρατία
# [118/142] Procesando «FotiniPipili»…
#   – Sin datos obtenidos
# [119/142] Procesando «Chris Dermentzopoulos»…
#   – Sin datos obtenidos
# [120/142] Procesando «George Katrougalos/Γιώργος Κατρούγκαλος»…
#   – Sin datos obtenidos
# [121/142] Procesando «Elena Rapti»…
#   ✓ edad: 49, género: femenino, partido: Νέα Δημοκρατία
# [122/142] Procesando «Χρήστος Σπίρτζης»…
#   ✓ edad: 56, género: masculino, partido: Πανελλήνιο Σοσιαλιστικό Κίνημα
# [123/142] Procesando «Themis Cheimaras»…
#   – Sin datos obtenidos
# [124/142] Procesando «Γιάννης Οικονόμου»…
#   ✓ edad: 61, género: masculino, partido: N/A
# [125/142] Procesando «Νίνα Γ. Κασιμάτη»…
#   – Sin datos obtenidos
# [126/142] Procesando «Σάκης Παπαδόπουλος»…
#   ✓ edad: 73, género: masculino, partido: Συνασπισμός Ριζοσπαστικής Αριστεράς - Προοδευτική Συμμαχία
# [127/142] Procesando «Makis Voridis»…
#   ✓ edad: 60, género: masculino, partido: Νέα Δημοκρατία
# [128/142] Procesando «Miltos Chrysomallis»…
#   – Sin datos obtenidos
# [129/142] Procesando «Σαμαράς Αντώνης»…
#   – Sin datos obtenidos
# [130/142] Procesando «Μάξιμος Σενετάκης»…
#   – Sin datos obtenidos
# [131/142] Procesando «Μαριλένα Σούκουλη Βιλιαλη»…
#   – Sin datos obtenidos
# [132/142] Procesando «Burhan Baran»…
#   – Sin datos obtenidos
# [133/142] Procesando «Kostas Vlasis»…
#   – Sin datos obtenidos
# [134/142] Procesando «Antonios Mylonakis»…
#   ✓ edad: 66, género: masculino, partido: Λαϊκός Ορθόδοξος Συναγερμός
# [135/142] Procesando «George Arvanitidis»…
#   – Sin datos obtenidos
# [136/142] Procesando «Vartzopoulos»…
#   – Sin datos obtenidos
# [137/142] Procesando «Σπύρος Λάππας»…
#   – Sin datos obtenidos
# [138/142] Procesando «Γιάννης Μπουρνούς - Yiannis Bournous»…
#   – Sin datos obtenidos
# [139/142] Procesando «ΚΩΝΣΤΑΝΤΙΝΟΠΟΥΛΟΣ ΟΔΥΣΣΕΑΣ»…
#   – Sin datos obtenidos
# [140/142] Procesando «Av. İlhan AHMET»…
#   – Sin datos obtenidos
# [141/142] Procesando «Kostis Hatzidakis»…
#   – Sin datos obtenidos
# [142/142] Procesando «Βασίλης Διγαλάκης»…
#   ✓ edad: 62, género: masculino, partido: Νέα Δημοκρατία
#
# ✅ Archivo generado: politicos_griegos.xlsx
